jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 closed up 0.1 per cent, with a 1.8 per cent decline for Goldman Sachs helping to keep gains in check. The technology-heavy Nasdaq Composite ended the day flat....',
#   '2023-04-18T20:29:58+0000'),
#  ('FirstFT: China’s economy beats forecasts to grow 4.5% in first quarter',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F36c02b09-3ce2-4fbb-b61b-671f37a9fe20.png?source=next&fit=scale-down&dpr=2&width=240',
#   '...US futures were tipped to open flat, with the blue-chip S&P 500 and tech-heavy Nasdaq poised to make minimal gains....',
#   '2023-04-18T10:26:47+0000'),
#  ('Is Schwab cheap? Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F173dd444-0e1b-4abe-9d9c-88de0653f243.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...He also objects to Universa’s claim that, “an investor with 98 per cent in the S&P 500 and 2 per cent in Universa would have seen their money grow an average 11.8 per cent annually in the firm’s 15-year...',
#   '2023-04-18T05:30:46+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US stocks advance after mixed bag of earnings',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fab22a7a4-c41e-4d5f-b308-bb854f40fdd8.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Wall Street’s benchmark S&P 500 and the tech-heavy Nasdaq Composite both ended 0.3 per cent higher....',
#   '2023-04-17T20:45:16+0000'),
#  ('Merck/Prometheus: Big Pharma must swallow bigger premiums   Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F31c430aa-ff0e-4428-916c-7debc1a68946.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The New Jersey pharmaceutical titan’s share price has doubled in the past five years, well ahead of the wider S&P 500 index....',
#   '2023-04-17T17:28:17+0000'),
#  ('Mood turns dark with new bank figures Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F661604a4-d815-44fc-a99a-f71df6d34bde.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Despite the mixed picture this paints concerning the health of the banking sector, Wall Street’s S&P 500 was up in early US trading and Europe’s Stoxx 600 rose 0.1 per cent....',
#   '2023-04-17T17:15:47+0000'),
#  ('European shares rise as bank contagion fears ease',
#   'None',
#   '...Across the Atlantic, contracts tracking Wall Street’s benchmark S&P 500 and the tech-heavy Nasdaq 100 were both up 0.3 per cent ahead of the New York open....',
#   '2023-04-17T07:51:11+0000'),
#  ('Margins will fall, but to where?  Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fe5344fbf-cc0e-4234-b784-e2b0b3ad34a5.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Higher, even, than the numbers followed most closely by Wall Street — S&P 500 operating margins — would suggest....',
#   '2023-04-17T05:31:46+0000'),
#  ('Asset Management: Cracks in European commercial real estate',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F884324b0-7aac-4643-9e7b-10e50e32e78f.png?source=next&fit=scale-down&dpr=2&width=240',
#   '...The Cac 40 has risen 16 per cent so far this year and by more than 30 per cent since a low at the end of September, outperforming Europe’s region-wide Stoxx 600 and the US S&P 500 over the same period....',
#   '2023-04-17T05:00:47+0000'),
#  ('What to watch in Europe today',
#   'None',
#   '...Economic data: S&P Global releases its UK regional purchasing managers’ index. Deloitte publishes its annual survey of chief financial officers....',
#   '2023-04-17T04:00:14+0000'),
#  ('Investors rethink risk after Credit Suisse bonds wiped out',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F04353b85-faff-458d-ba42-5a1502abcb02.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Michelle Brennan, credit analyst at S&P Global Ratings, says investors now understand that other countries “may not automatically follow the Swiss pattern”....',
#   '2023-04-17T04:00:04+0000'),
#  ('Check-up on China’s economy ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F6e98b118-e595-4df0-83cf-0a0522915e66.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...P Global\n\nUS, former Amazon executive David Risher is appointed the new boss of ride-hailing app Lyft, replacing the founders of the app Logan Green and John Zimmer....',
#   '2023-04-16T17:00:03+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US executive pay bucked falling stock market in 2022',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fe37d6dbd-f08b-448a-bd82-a6b33a9a6161.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The analysis shows that many executives continued to enjoy big pay awards despite a 19 per cent drop for the benchmark S&P 500 index last year, the biggest fall since 2008....',
#   '2023-04-16T11:00:02+0000'),
#  ('Sudan paramilitaries clash with army in struggle for power',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F556d2698-ff33-4a10-814e-267539135502.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...While Sudan only produces around 50,000 barrels a day South Sudan produces 140,000 b/d according to S&P Global Platts....',
#   '2023-04-15T16:57:36+0000'),
#  ('French stocks enjoy renaissance on back of Chinese demand for luxury',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fd031b484-ee94-4254-8e31-e6abc833d6f0.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The Cac 40 has risen 16 per cent so far this year and by more than 30 per cent since a low at the end of September, outperforming Europe’s region-wide Stoxx 600 and the US S&P 500 over the same period....',
#   '2023-04-15T13:00:49+0000'),
#  ('A weekend among the gods at America’s premier crossword competition',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F9c67c619-34e5-4c5d-bf4c-5c6bb6c7bbc5.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...It could conceivably be an M or a P, or perhaps something else entirely. While Pasco was pondering this choice, Feyer swept through his own empty squares and raised his hand....',
#   '2023-04-15T04:00:28+0000'),
#  ('US stocks end week higher as big banks beat expectations',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Ff749b6bf-2db2-489f-9158-76a8b48121e6.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Still, the blue-chip S&P 500 declined 0.2 per cent on Friday, but added 0.8 per in the week. The tech-heavy Nasdaq Composite lost 0.4 per cent on Friday, but gained 0.3 per cent across five sessions....',
#   '2023-04-14T20:32:34+0000'),
#  ('Banks crisis looks short but lessons must be more enduring',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fdbdd8a51-8b03-49ba-87e8-56525291e617.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Since then, the S&P 500 has risen about 7 per cent — a nose ahead of global stocks and more than making up for the sell-off just before SVB’s demise. Calm before the storm? Maybe....',
#   '2023-04-14T19:00:28+0000'),
#  ('The Lex Newsletter: a Spac clapback Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F78a0e772-f4d1-410c-a85c-aec7bbd515cd.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Last year, Spac listings dropped 86 per cent compared with the previous year, according to S&P data. This year may be even lower.\n\nSpacs are shell entities that give companies a backdoor into markets....',
#   '2023-04-14T16:00:28+0000'),
#  ('European stocks advance as rate fears recede',
#   'None',
#   '...In futures markets, the blue-chip S&P 500 and the tech-heavy Nasdaq Composite was set to trade flat....',
#   '2023-04-14T10:07:25+0000'),
#  ('IHG: listing questions keep Holiday Inn owner occupied',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F3e02af79-fa09-493f-b16a-b6ab5f13ae8e.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Marriott trades on more than 14 times and Hilton nearly 16 times, according to data provider S&P Capital IQ.\n\nEven so, that gap does not look huge....',
#   '2023-04-14T04:00:32+0000'),
#  ('Asian stocks advance after weak US inflation data boosts sentiment',
#   'None',
#   '...The S&P 500 rose 1.3 per cent on Thursday, closing at its highest level since February 15. The Nasdaq Composite gained 1.9 per cent....',
#   '2023-04-14T00:07:15+0000'),
#  ('Wall Street stocks mixed as investors assess US earnings',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F93883925-d5b0-4aca-b67b-d87c649594b2.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 was flat in afternoon trade in New York. The tech-heavy Nasdaq Composite, which is up 15 per cent this year, added 0.1 per cent....',
#   '2023-04-19T19:57:40+0000'),
#  ('Fisking Moulding’s fulmination',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fbcb27baf-58e3-47b7-8b74-fa0845010ef2.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...That’s a lower proportion than the S&P 500, which has 13 stocks above the 10 per cent short threshold. And from 461 companies in the Stoxx 600 ex UK, 28 are heavily shorted....',
#   '2023-04-19T15:27:19+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('The market is up — narrowly Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F947acf9a-17d7-4d5b-a176-7af6596fb52b.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 index has performed just fine since the eighth of March, rising about 4 per cent....',
#   '2023-04-19T05:30:36+0000'),
#  ('Wall Street stocks subdued after mixed earnings reports',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F0b0dbbaf-5342-46b5-b6d7-fd503d0233ed.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 closed up 0.1 per cent, with a 1.8 per cent decline for Goldman Sachs helping to keep gains in check. The technology-heavy Nasdaq Composite ended the day flat....',
#   '2023-04-18T20:29:58+0000'),
#  ('FirstFT: China’s economy beats forecasts to grow 4.5% in first quarter',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F36c02b09-3ce2-4fbb-b61b-671f37a9fe20.png?source=next&fit=scale-down&dpr=2&width=240',
#   '...US futures were tipped to open flat, with the blue-chip S&P 500 and tech-heavy Nasdaq poised to make minimal gains....',
#   '2023-04-18T10:26:47+0000'),
#  ('Is Schwab cheap? Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F173dd444-0e1b-4abe-9d9c-88de0653f243.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...He also objects to Universa’s claim that, “an investor with 98 per cent in the S&P 500 and 2 per cent in Universa would have seen their money grow an average 11.8 per cent annually in the firm’s 15-year...',
#   '2023-04-18T05:30:46+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US stocks advance after mixed bag of earnings',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fab22a7a4-c41e-4d5f-b308-bb854f40fdd8.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Wall Street’s benchmark S&P 500 and the tech-heavy Nasdaq Composite both ended 0.3 per cent higher....',
#   '2023-04-17T20:45:16+0000'),
#  ('Merck/Prometheus: Big Pharma must swallow bigger premiums   Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F31c430aa-ff0e-4428-916c-7debc1a68946.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The New Jersey pharmaceutical titan’s share price has doubled in the past five years, well ahead of the wider S&P 500 index....',
#   '2023-04-17T17:28:17+0000'),
#  ('Mood turns dark with new bank figures Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F661604a4-d815-44fc-a99a-f71df6d34bde.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Despite the mixed picture this paints concerning the health of the banking sector, Wall Street’s S&P 500 was up in early US trading and Europe’s Stoxx 600 rose 0.1 per cent....',
#   '2023-04-17T17:15:47+0000'),
#  ('European shares rise as bank contagion fears ease',
#   'None',
#   '...Across the Atlantic, contracts tracking Wall Street’s benchmark S&P 500 and the tech-heavy Nasdaq 100 were both up 0.3 per cent ahead of the New York open....',
#   '2023-04-17T07:51:11+0000'),
#  ('Margins will fall, but to where?  Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fe5344fbf-cc0e-4234-b784-e2b0b3ad34a5.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Higher, even, than the numbers followed most closely by Wall Street — S&P 500 operating margins — would suggest....',
#   '2023-04-17T05:31:46+0000'),
#  ('Asset Management: Cracks in European commercial real estate',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F884324b0-7aac-4643-9e7b-10e50e32e78f.png?source=next&fit=scale-down&dpr=2&width=240',
#   '...The Cac 40 has risen 16 per cent so far this year and by more than 30 per cent since a low at the end of September, outperforming Europe’s region-wide Stoxx 600 and the US S&P 500 over the same period....',
#   '2023-04-17T05:00:47+0000'),
#  ('What to watch in Europe today',
#   'None',
#   '...Economic data: S&P Global releases its UK regional purchasing managers’ index. Deloitte publishes its annual survey of chief financial officers....',
#   '2023-04-17T04:00:14+0000'),
#  ('Investors rethink risk after Credit Suisse bonds wiped out',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F04353b85-faff-458d-ba42-5a1502abcb02.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Michelle Brennan, credit analyst at S&P Global Ratings, says investors now understand that other countries “may not automatically follow the Swiss pattern”....',
#   '2023-04-17T04:00:04+0000'),
#  ('Check-up on China’s economy ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F6e98b118-e595-4df0-83cf-0a0522915e66.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...P Global\n\nUS, former Amazon executive David Risher is appointed the new boss of ride-hailing app Lyft, replacing the founders of the app Logan Green and John Zimmer....',
#   '2023-04-16T17:00:03+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US executive pay bucked falling stock market in 2022',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fe37d6dbd-f08b-448a-bd82-a6b33a9a6161.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The analysis shows that many executives continued to enjoy big pay awards despite a 19 per cent drop for the benchmark S&P 500 index last year, the biggest fall since 2008....',
#   '2023-04-16T11:00:02+0000'),
#  ('Sudan paramilitaries clash with army in struggle for power',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F556d2698-ff33-4a10-814e-267539135502.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...While Sudan only produces around 50,000 barrels a day South Sudan produces 140,000 b/d according to S&P Global Platts....',
#   '2023-04-15T16:57:36+0000'),
#  ('French stocks enjoy renaissance on back of Chinese demand for luxury',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fd031b484-ee94-4254-8e31-e6abc833d6f0.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The Cac 40 has risen 16 per cent so far this year and by more than 30 per cent since a low at the end of September, outperforming Europe’s region-wide Stoxx 600 and the US S&P 500 over the same period....',
#   '2023-04-15T13:00:49+0000'),
#  ('A weekend among the gods at America’s premier crossword competition',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F9c67c619-34e5-4c5d-bf4c-5c6bb6c7bbc5.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...It could conceivably be an M or a P, or perhaps something else entirely. While Pasco was pondering this choice, Feyer swept through his own empty squares and raised his hand....',
#   '2023-04-15T04:00:28+0000'),
#  ('US stocks end week higher as big banks beat expectations',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Ff749b6bf-2db2-489f-9158-76a8b48121e6.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Still, the blue-chip S&P 500 declined 0.2 per cent on Friday, but added 0.8 per in the week. The tech-heavy Nasdaq Composite lost 0.4 per cent on Friday, but gained 0.3 per cent across five sessions....',
#   '2023-04-14T20:32:34+0000'),
#  ('Banks crisis looks short but lessons must be more enduring',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fdbdd8a51-8b03-49ba-87e8-56525291e617.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Since then, the S&P 500 has risen about 7 per cent — a nose ahead of global stocks and more than making up for the sell-off just before SVB’s demise. Calm before the storm? Maybe....',
#   '2023-04-14T19:00:28+0000'),
#  ('The Lex Newsletter: a Spac clapback Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F78a0e772-f4d1-410c-a85c-aec7bbd515cd.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Last year, Spac listings dropped 86 per cent compared with the previous year, according to S&P data. This year may be even lower.\n\nSpacs are shell entities that give companies a backdoor into markets....',
#   '2023-04-14T16:00:28+0000'),
#  ('European stocks advance as rate fears recede',
#   'None',
#   '...In futures markets, the blue-chip S&P 500 and the tech-heavy Nasdaq Composite was set to trade flat....',
#   '2023-04-14T10:07:25+0000'),
#  ('IHG: listing questions keep Holiday Inn owner occupied',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F3e02af79-fa09-493f-b16a-b6ab5f13ae8e.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Marriott trades on more than 14 times and Hilton nearly 16 times, according to data provider S&P Capital IQ.\n\nEven so, that gap does not look huge....',
#   '2023-04-14T04:00:32+0000'),
#  ('Asian stocks advance after weak US inflation data boosts sentiment',
#   'None',
#   '...The S&P 500 rose 1.3 per cent on Thursday, closing at its highest level since February 15. The Nasdaq Composite gained 1.9 per cent....',
#   '2023-04-14T00:07:15+0000'),
#  ('What to watch in Asia today',
#   'None',
#   '...The S&P 500 rose 1.3 per cent. The Nasdaq Composite gained 1.9 per cent....',
#   '2023-04-14T00:05:45+0000'),
#  ('Letter: Peculiarity of the diesel price slump explained',
#   'None',
#   '...Rebeka Foley Senior Analyst, Oil Markets, Europe & Russia, S&P Global Commodity InsightsLondon E14, UK...',
#   '2023-04-13T23:00:32+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US stocks jump as investors bet on slowing interest rates',
#   'None',
#   '...The blue-chip S&P 500 rose 1.3 per cent in New York, closing at its highest level since February 15. The tech-heavy Nasdaq gained 1.9 per cent....',
#   '2023-04-13T22:53:29+0000'),
#  ('Indonesia’s GoTo far from profitability one year after listing',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F991ca260-2f89-43e1-ab83-b27ca8fba0b4.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...GoTo’s market capitalisation now stands at Rp104tn according to S&P Capital IQ, making it the 14th largest on the IDX....',
#   '2023-04-13T22:00:32+0000'),
#  ('US stocks jump as investors bet on slowing interest rates',
#   'None',
#   '...The blue-chip S&P 500 rose 1.3 per cent in New York, closing at its highest level since February 15. The tech-heavy Nasdaq gained 1.9 per cent....',
#   '2023-04-13T21:16:43+0000'),
#  ('US stocks jump as investors bet on slowing interest rates',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fefaf3b24-eed5-47a4-88b9-c5cf25b955f4.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The blue-chip S&P 500 rose 1.3 per cent in New York, closing at its highest level since February 15. The tech-heavy Nasdaq gained 1.9 per cent....',
#   '2023-04-13T20:48:39+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Marex IPO: footloose broker resists commoditisation  Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F5a2c4f76-e235-4b58-a6da-45af24f4e4f1.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The slower-growing UK broker is on 7 times this year’s expected profits, according to S&P Capital IQ. A better marker might be StoneX, on 9.6 times 2023 earnings....',
#   '2023-04-13T17:00:14+0000'),
#  ('Euro surges to 12-month high as investors bet on more ECB rate rises',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F8dea4341-904d-463f-8fcf-226c2c0e8f36.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Business activity in the 20-country single currency bloc also expanded at its fastest rate for 10 months in March, according to a survey of purchasing managers published by S&P Global last month....',
#   '2023-04-13T16:22:44+0000'),
#  ('Tesco: operations resilient amid battle of many fronts Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F65838a4a-6111-4309-ab05-5b804097ef18.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...But they are still below pre-pandemic levels of nearly 14 times, according to S&P Capital IQ....',
#   '2023-04-13T14:42:37+0000'),
#  ('Crocs: ugly shoe trend is a thing of beauty for investors Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fbe231eb1-8c70-4a9e-959c-ca91562d521e.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...That compares to Nike’s 4 per cent decline and the S&P 500’s 7 per cent drop over the same period....',
#   '2023-04-13T12:20:14+0000'),
#  ('FirstFT: Fed warns of ‘mild’ recession this year ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F662008e7-f1a8-42b7-b3f7-8c12be8c6b34.png?source=next&fit=scale-down&dpr=2&width=240',
#   '...Ultimately, though the FOMC decided to press ahead with a quarter-point rise to a new target range of 4.75 per cent to 5 per cent, but the minutes helped send the benchmark S&P 500 down 0.4 per cent by yesterday...',
#   '2023-04-13T09:55:59+0000'),
#  ('Commercial real estate is bruised but not broken',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F4803a9d4-f9a6-4975-b15f-06ba814ad0a0.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...According to S&P Global, the number of banks exceeding regulatory guidance on CRE loan concentration rose for the seventh consecutive quarter in the final three months of last year....',
#   '2023-04-13T04:00:02+0000'),
#  ('Flows into ETFs treble in March as investors seek safety',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F1e0ee788-50e4-498c-a7f0-647e9d75a84d.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...P Regional Banking ETF] and XLF [the Financial Select Sector SPDR Fund] having net inflows for March,” said Rosenbluth, although he added that ETF shares “are often created to support shorting purposes”,...',
#   '2023-04-13T04:00:02+0000'),
#  ('Asian stocks down after Fed officials predict ‘mild’ recession this year',
#   'None',
#   '...Those moves followed declines on Wednesday in the US, where the S&P 500 closed 0.4 per cent lower and the Nasdaq Composite dropped 0.9 per cent after minutes from the Fed’s March meeting revealed officials...',
#   '2023-04-13T02:15:42+0000'),
#  ('What to watch in Asia today',
#   'None',
#   '...The S&P 500 closed 0.4 per cent lower and the Nasdaq Composite dropped 0.9 per cent....',
#   '2023-04-12T23:21:13+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US stocks edge lower as Federal Reserve officials predict ‘mild recession’',
#   'None',
#   '...The benchmark S&P 500 closed 0.4 per cent lower while the tech-heavy Nasdaq Composite dropped 0.9 per cent....',
#   '2023-04-12T22:54:33+0000'),
#  ('US stocks edge lower as Federal Reserve officials predict ‘mild recession’',
#   'None',
#   '...The benchmark S&P 500 closed 0.4 per cent lower while the tech-heavy Nasdaq Composite dropped 0.9 per cent....',
#   '2023-04-12T21:32:01+0000'),
#  ('US stocks slide as Fed officials predict ‘mild recession’',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F36094c53-0eb4-4cc0-b12e-be5170c4b0d1.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The benchmark S&P 500 closed 0.4 per cent lower while the tech-heavy Nasdaq Composite dropped 0.9 per cent....',
#   '2023-04-12T20:46:00+0000'),
#  ('IHG: no permanent Holiday Inn New York just yet Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F21cb106c-e03b-4dc1-8347-c79c1a636a5a.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Marriott trades on more than 14 times and Hilton nearly 16 times, according to S&P Capital IQ.\n\nEven so, that gap does not look huge....',
#   '2023-04-12T16:29:30+0000'),
#  ('US stock futures climb after inflation slows',
#   'None',
#   '...Contracts tracking Wall Street’s benchmark S&P 500 rose 0.9 per cent while those tracking the tech-heavy Nasdaq 100 added 1.1 per cent ahead of the New York open....',
#   '2023-04-12T12:42:41+0000'),
#  ('An annus horribilis for UK stockpickers',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Facaeaaa8-80f3-4a87-9c05-dba97bc37dfc.png?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 EUR and S&P 500 GBP outperformed their currency hedged counterparts by 7.8% and 12.2%, respectively, and with lower volatility....',
#   '2023-04-12T10:00:20+0000'),
#  ('European stocks edge higher as investors await US inflation figures',
#   'None',
#   '...Contracts tracking Wall Street’s benchmark S&P 500 were flat while those tracking the tech-heavy Nasdaq 100 slipped 0.1 per cent ahead of the New York open....',
#   '2023-04-12T08:15:19+0000'),
#  ('European aviation industry claims bill of €\u200e800bn to reach net zero emissions',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F7a2622be-c3e9-41e7-9ab9-408e54edcfdd.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...A separate analysis from S&P Global, a rating agency, this month found that planes “currently have no cost-effective alternative to fossil fuels”....',
#   '2023-04-12T04:00:21+0000'),
#  ('US stocks mixed as investors await inflation data and earnings',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F44b52187-c9a6-4584-b71b-ca9a28fcdbca.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The blue-chip S&P 500 ended the day flat, with every sector in positive territory except tech and communications, down 1 per cent and 0.4 per cent, respectively....',
#   '2023-04-11T20:45:32+0000'),
#  ('Newmont/Newcrest: buffed-up offer may lead to golden handshake  Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fb8bd3c4b-531e-4eef-b1e5-1c4a3b909b61.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...That values Newcrest at an enterprise value of A$32bn ($21.3bn), almost 10 times this year’s expected ebitda, according to S&P Capital IQ. At least one big shareholder is inclined to accept....',
#   '2023-04-11T15:11:25+0000'),
#  ('EU diesel: refiners’ crack of boom forestalled by slower growth Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F175ba5b1-34fd-4b6b-8be1-1c8989c801d3.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Letter in response to this column:\n\nPeculiarity of the diesel price slump explained\xa0/\xa0From Rebeka Foley, Senior Analyst, Oil Markets, Europe & Russia, S&P Global Commodity Insights, London E14, UK...',
#   '2023-04-11T11:09:46+0000'),
#  ('The spring in Wall Street’s step isn’t justified Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F38e28f1c-5dfc-417b-8b84-35ceed3134b5.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...They’ve done this in the case of the S&P 500 by shunning a few affected players (First Republic Bank, down 83 per cent) while bidding up mega-caps such as Microsoft, up 16 per cent....',
#   '2023-04-11T05:30:44+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Rise of the Russian informer',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fcf8f909c-d171-4e7a-879b-d09f02d2abaf.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Companies in the S&P 500 index are expected to report a nearly 7 per cent decline in first-quarter earnings....',
#   '2023-04-11T04:00:45+0000'),
#  ('Rise of the Russian informer ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fuploaded-files%2Fft-news-briefing-2e004171-2412-45a7-969b-31ddb3890ac8.png?source=next&fit=scale-down&dpr=2&width=240',
#   '...Companies on the S&P 500 index are expected to report a 6.8 per cent decline in first-quarter earnings, Eli Lilly’s CEO told the Financial Times that Europe may miss out on new drugs if it pushes ahead with...',
#   '2023-04-11T04:00:04+0000'),
#  ('Asian equities rise as traders assess US interest rate outlook',
#   'None',
#   '...The S&P 500 closed 0.1 per cent higher, while the tech-heavy Nasdaq Composite ended the day flat....',
#   '2023-04-10T23:01:25+0000'),
#  ('Fed interest rate rise fears weigh as US markets reopen post-Easter',
#   'None',
#   '...The S&P 500 closed 0.1 per cent higher after a late pick-up, while the tech-heavy Nasdaq Composite ended the day flat despite dropping as much as 1.4 per cent in early trading....',
#   '2023-04-10T22:58:30+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Fed rate rise fears weigh on US stocks',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F7dc77da8-708b-412f-9dfb-0f972af9930d.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 closed 0.1 per cent higher after a late pick-up, while the tech-heavy Nasdaq Composite ended the day flat despite dropping as much as 1.4 per cent in early trading....',
#   '2023-04-10T20:16:53+0000'),
#  ('US stocks hold as traders weigh another Fed rate rise',
#   'None',
#   '...The S&P 500 closed 0.1 per cent higher after a late rally, while the tech-heavy Nasdaq Composite ended the day flat after dropping as much as 1.4 per cent in early trading....',
#   '2023-04-10T20:08:42+0000'),
#  ('US companies face biggest decline in profits since Covid shutdowns',
#   'None',
#   '...Companies on the S&P 500 index are expected to report a 6.8 per cent decline in first-quarter earnings compared with the same period a year earlier, according to analyst estimates compiled by FactSet....',
#   '2023-04-10T17:06:03+0000'),
#  ('US companies face biggest decline in profits since Covid shutdowns',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Faa16b23d-bf5f-4d3f-9893-c5630456204c.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Of the 11 sectors in the S&P 500, materials is expected to take the worst earnings hit, with a 35.6 per cent decline forecast....',
#   '2023-04-10T15:49:08+0000'),
#  ('Fed rate rise fears weigh on US stocks',
#   'None',
#   '...The S&P 500 slid 0.8 per cent in early trading, while the tech-heavy Nasdaq Composite fell 1.1 per cent....',
#   '2023-04-10T14:05:47+0000'),
#  ('European commercial real estate: the cracks are starting to show',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F7d4463f0-efbd-49a4-8118-d7472cdc09bc.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...HSBC, whose real estate lending has grown in recent years, still had only 11 per cent exposure, S&P said.\n\nBanks are not the only lenders, however....',
#   '2023-04-10T04:00:37+0000'),
#  ('Twenty S&P 500 stocks account for 90% of Wall Street’s gains this year',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F784d6211-d6d6-4b8a-a3d3-d98251b03594.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Ignoring gains for megacap growth stocks, the S&P 500 rose just 1.4 per cent in the first three months of 2023, said UBS....',
#   '2023-04-08T13:00:27+0000'),
#  ('US investors increase investments in foreign equities',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F4cc93455-9a16-405b-a235-51e2f5d76786.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The market capitalisation of the S&P 500 stands at $34tn, compared with just under €10tn on the Euro Stoxx 600....',
#   '2023-04-08T03:00:56+0000'),
#  ('Traditional investors are learning it’s tricky to be picky ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fcd9f2b48-7f26-46dc-adea-f2e3929b2890.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...“The S&P is very overpriced versus the rest of the world,” he said. “We prefer brighter pastures overseas like China and Hong Kong. They are just coming out of recession while we’re going into one....',
#   '2023-04-07T19:00:55+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Opec’s gamble: can the global economy cope with higher oil prices?',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F4b9d2489-f085-4d55-af10-376cc5e6c1fa.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...As the Saudis and other producers cut crude exports between May and the end of the year, demand for the kind of oil sold by Russia will increase, says Roger Diwan, a veteran Opec-watcher at S&P Global Commodity...',
#   '2023-04-07T18:30:55+0000'),
#  ('Why I won’t be pondering sterling’s rally down the pub',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F7c16c30c-1c85-4a60-8913-ab6f20e34d46.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...For example, the base currency for my S&P 500 ETF is dollars and I own a sterling version....',
#   '2023-04-07T04:00:35+0000'),
#  ('US stocks rise as investors await crucial jobs report',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fd4289ae1-8b74-426a-addb-789b1ef4c03e.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The benchmark S&P 500 recovered from an earlier decline to close up 0.4 per cent with tech and utilities tempering falls for energy, basic materials and consumer cyclical industries....',
#   '2023-04-06T20:41:31+0000'),
#  ('The long party in tech stocks is not over yet',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F391e2a4d-24c8-4953-884b-49e3ea82632b.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Their combined market cap has jumped 25 per cent since the start of 2023, at a time when the S&P 500 index is up only 7 per cent....',
#   '2023-04-06T18:20:05+0000'),
#  ('US stocks edge higher as investors assess outlook for labour market',
#   'None',
#   '...The benchmark S&P 500 recovered from an earlier decline to trade 0.2 per cent at 1pm local time, with energy, basic materials and consumer cyclicals the worst performers....',
#   '2023-04-06T17:04:58+0000'),
#  ('How should we regulate ESG research?',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F652b0ebe-9cce-4867-a44c-61f5250b69e4.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...But MSCI’s correlation with both S&P and Sustainalytics is below 50%. The S&P and Sustainalytics correlation is higher but still lower than expected\u2009.\u2009.\u2009....',
#   '2023-04-06T17:02:40+0000'),
#  ('Opec puts the power of the Russian price cap to the test Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F67ce02ba-fe65-413e-99c3-63afa8b26a33.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...But as Karim Fawaz, an analyst at S&P Global, points out, the success of the policy has been helped by a loose crude market, with lower prices and excess supply....',
#   '2023-04-06T11:00:35+0000'),
#  ('UK house prices rose unexpectedly in March, says Halifax',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fd0e2b0f0-2e2c-4998-a17b-59c04ce9c8ed.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P Global/Cips construction purchasing managers’ index, a measure of activity in the sector, showed on Thursday that builders reported the fastest decline in housing activity in March since May 2020...',
#   '2023-04-06T10:14:13+0000'),
#  ('UK housebuilding slows as borrowing costs knock demand ',
#   'None',
#   '...“A sharp and accelerated decline in house building was the main area of concern,” said Tim Moore, economics director at S&P Global Market Intelligence....',
#   '2023-04-06T08:50:51+0000'),
#  ('European stocks edge higher and Wall Street futures slip on jobs data',
#   'None',
#   '...In the US, contracts tracking the benchmark S&P 500 and the tech-heavy Nasdaq 100 both fell less than 0.1 per cent ahead of the New York open. Both indices had fallen on Wednesday....',
#   '2023-04-06T08:17:34+0000'),
#  ('No margin compression, no ’23 recession Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fbaf3119d-665e-41b5-94d3-5c4d0c8a8e12.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...As Edwards points out, if you looked only at reported corporate earnings for the S&P 500, you would think that “greedflation” (his term for companies taking what they can) was starting to taper off....',
#   '2023-04-06T05:30:31+0000'),
#  ('What to watch in Europe today',
#   'None',
#   '...UK economy: A new fiscal year starts in Britain, while S&P Global releases its construction purchasing managers’ index data....',
#   '2023-04-06T04:32:13+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('What does it mean to be a boy online in 2023?',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F481835d3-3545-4a55-b032-318dc3738b40.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...“K-S-I! K-S-I! K-S-I!” they chanted.\n\nAt 10.30pm, after several other YouTubers-cum-boxers had taken their turns in the ring, KSI appeared. He wore a pink outfit and sang the national anthem....',
#   '2023-04-06T04:00:32+0000'),
#  ('Asian stocks follow the US lower on recession fears',
#   'None',
#   '...US equities slipped on Wednesday, with the S&P 500 losing 0.2 per cent and the Nasdaq Composite down 1.2 per cent after the release of a two sets of weaker-than-expected jobs data this week....',
#   '2023-04-06T02:53:40+0000'),
#  ('Asia’s growth companies buck a slowing trend',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fb06eaad0-9799-4076-b383-2a7b0fdf2032.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Major benchmark indices including Japan now trade at a discount of around a third to the S&P 500 index based on forward earnings valuations. New listing pipelines remain slow....',
#   '2023-04-06T00:00:31+0000'),
#  ('What to watch in Asia today',
#   'None',
#   '...US Equities slipped on Wednesday, with the blue-chip S&P 500 losing 0.2 per cent, as investors appeared to eschew growth stocks for more defensive sectors after the release of softer economic data ....',
#   '2023-04-05T23:11:37+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US Treasury yields sink to seven-month low on weak data',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F68b0fbb1-367c-4a6e-aeb1-eede0981df7a.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Equities slipped in the session, with the blue-chip S&P 500 losing 0.2 per cent, as investors appeared to eschew growth stocks for more defensive sectors, which tend to be more resilient in a downturn....',
#   '2023-04-05T20:44:21+0000'),
#  ('Hedge funds made $7bn from betting against banks during turmoil',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F50abff32-53a9-4c7f-ac0c-46d11201f0a7.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Bets against Credit Suisse, for instance, were running at just 3.5 per cent of the bank’s outstanding shares at the start of March, according to S&P Global Market Intelligence, as measured by shares out...',
#   '2023-04-05T20:00:31+0000'),
#  ('A slowly slowing economy Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F97cdb90c-b951-4a30-9839-8a733cd9c95a.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...(Ethan Wu)The tech bounce\n\nHere’s a chart:\n\nThose are of six of the seven best-performing stocks in the S&P 500 year to date....',
#   '2023-04-05T05:30:38+0000'),
#  ('What to watch in Europe today',
#   'None',
#   '...Economic data: S&P Global releases its final services purchasing manager’s index data for the EU, France, Germany, Italy and the UK. France releases its industrial production figures for February....',
#   '2023-04-05T04:51:35+0000'),
#  ('EU stock trading plans risk hurting small investors, warns Euronext CEO',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F8a3ed367-510c-4dd6-b5cc-505735595364.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The European Fund and Asset Management Association, which represents more than 4,500 asset managers in the EU, has advocated for its creation, saying it would provide investors with greater transparency....',
#   '2023-04-05T04:00:39+0000'),
#  ('Japanese equities down on weak US labour data',
#   'None',
#   '...While the data buoyed hopes that the Federal Reserve would soon hit the brakes on interest rate increases, the S&P 500 closed down 0.6 per cent, snapping a four-day rally, and the Nasdaq Composite dropped...',
#   '2023-04-05T01:57:30+0000'),
#  ('Wall Street suffers $1.5bn loss on Citrix buyout loans',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Ff09dedda-ec65-4979-bbee-ace32ad1ca00.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...S&P has rated the bonds single-B minus, among the riskiest ratings it assigns....',
#   '2023-04-04T22:40:11+0000'),
#  ('US Treasuries rally and dollar falls on signs of cooling labour market',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F71078551-1995-4f9d-aba9-03243e5e7100.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 fell 0.6 per cent, ending a four-day rally, while the tech-heavy Nasdaq Composite dropped 0.5 per cent, as markets weighed the potential effect of a cooling labour market on economic growth and...',
#   '2023-04-04T20:43:44+0000'),
#  ('US Treasuries rally, stocks fall, after job openings data',
#   'None',
#   '...Wall Street’s S&P 500 and Nasdaq Composite were each down 0.8 per cent as markets weighed the potential impact of a cooling labour market on economic growth and inflation....',
#   '2023-04-04T19:00:50+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Glencore’s bid for Teck Resources revives animal spirits in race for copper',
# ...
#   '...David Pilling\n\nWill the S&P 500 fall by at least 10 per cent?\n\nYes. We asked this question last year, but it bears repeating....',
#   '2022-12-30T21:00:07+0000'),
#  ('US central bankers hope lower profit margins will aid inflation fight',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F5d3ca49f-e636-49dc-81bb-9c4e8e7fdb1e.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Pre-tax profits for S&P 500 companies hit an all-time high in the second quarter of this year, US Bureau of Economic Analysis data show....',
#   '2022-12-30T05:00:06+0000'),
#  ('US stocks rise as investors weigh China Covid surge',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Ff50ca064-983a-4954-b4d0-dc69dbd70bad.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The benchmark S&P 500 rose 1.7 per cent and Nasdaq Composite 2.6 per cent as investors bought tech stocks such as Tesla, Netflix and Apple....',
#   '2022-12-29T21:29:59+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Oil and gas stocks shine in miserable year for US equities',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F011007c7-009e-4e67-8840-8e7f15ab985a.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Of the 25 performers in the benchmark S&P 500 index of stocks, as many as 15 will be fossil fuel operators....',
#   '2022-12-29T05:00:26+0000'),
#  ('War, inflation and tumbling markets: the year in 11 charts ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F7d0ac024-9bcb-49f2-9eae-3a5966311407.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 index is down 20 per cent from the start of the year; long-term bonds have had their worst year since the 18th century; and the long-established 60/40 investment strategy was hit with its worst...',
#   '2022-12-29T05:00:25+0000'),
#  ('Financial trends: more whacks for Spacs in 2023 Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F7a1cc6ab-d934-4bde-b1e5-ba99d1170b96.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 index lost 25 per cent over the period.\n\nFor investors, having Spac sponsors return their money in full with a bit of interest on top may well be a blessing in disguise....',
#   '2022-12-29T05:00:25+0000'),
#  ('Wall Street stocks slip after China softens Covid policy',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F0c1c4004-6763-4150-ac35-7c6e7d33b2f2.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Wall Street’s benchmark S&P 500 fell 1.2 per cent, while the tech-heavy Nasdaq Composite fell 1.4 per cent....',
#   '2022-12-28T21:42:45+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Big coal miners’ profits triple as demand surges ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fd2f204b6-6b10-4df7-b829-86a8b0487d8f.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...P Capital IQ....',
#   '2022-12-28T17:00:49+0000'),
#  ('Three ways Big Tech got it wrong',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F557cb068-427f-447d-a289-b56df086b7a7.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...S&P Global Mobility predicts it will fall below 20 per cent by 2025 as other makers bring out electric trucks and cheaper models faster than Tesla can build new factories....',
#   '2022-12-28T12:00:49+0000'),
#  ('FirstFT: Stocks fall after ‘Santa rally’ hopes are dashed',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F2d0c7049-7632-46d0-81f1-780499df3852.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 clawed back some early losses to close 0.4 per cent lower while the tech-heavy Nasdaq Composite index ended off 1.4 per cent....',
#   '2022-12-28T11:22:55+0000'),
#  ('Energy crunch will trigger eurozone contraction in 2023, economists warn',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F49db7c1f-a946-4c78-a430-a7c15488058c.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...P Global Ratings....',
#   '2022-12-28T05:00:49+0000'),
#  ('Hopes of ‘Santa rally’ in US stocks fade as megacaps struggle',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Ff103dc2e-2c73-4370-ab73-6c7ad71894e9.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...It topped the list of S&P 500 winners with a gain of 4.5 per cent....',
#   '2022-12-28T02:53:41+0000'),
#  ('Beijing changes tack on tackling property crisis',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F0a2e409d-6d6f-40c9-93d1-88865ad89ab4.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Then state-run banks pledged an eye-watering amount — around $256bn according to S&P — in potential credit to specific developers....',
#   '2022-12-28T00:01:49+0000'),
#  ('Lex hits and misses: ahead on market rout, behind on tech nuance Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F939a9a07-ba87-4cd5-9744-856200b90d99.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 has fallen 16 per cent since then....',
#   '2022-12-27T11:00:03+0000'),
#  ('Kensington’s property market conundrum',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F4273e4ca-9f3c-43be-8982-72f4f525fb5a.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...has been a busy year in the family house market — the number of transactions between January and November was 52 per cent higher than the five-year average leading to 2019 (though 7 per cent down on 2021’s...',
#   '2022-12-27T08:00:03+0000'),
#  ('US stocks close slightly higher on back of economic data',
#   'None',
#   '...The benchmark S&P 500 erased earlier losses to end 0.6 per cent higher, eventually dragging the Nasdaq Composite with it. The tech-heavy index closed up 0.2 per cent....',
#   '2022-12-23T21:41:18+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Tesla shares lose $85bn in market value over brutal week',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fd04b937d-4b13-4893-a3ef-d94cbc600086.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The drop of more than $800bn in value is equal to the combined current market capitalisation of more than 80 of the smallest companies in the S&P 500 index, according to S&P Global Market Intelligence....',
#   '2022-12-23T21:31:48+0000'),
#  ('Wall Street inches higher on back of economic data as holiday looms ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F60aac7cd-6afb-4ed9-a1d9-a300f9212e9f.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The benchmark S&P 500 erased earlier losses to end 0.6 per cent higher, eventually dragging the Nasdaq Composite with it. The tech-heavy index closed up 0.2 per cent....',
#   '2022-12-23T21:27:41+0000'),
#  ('Investors rush out of equity funds to end rough year',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F0a049e26-97ac-42f2-9b39-7db785a2f98e.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Wall Street’s S&P 500 rose 13 per cent from mid-October to the end of November but has fallen since then, with the Fed’s December move to slow its interest rate rises overshadowed by an increase in the central...',
#   '2022-12-23T18:39:59+0000'),
#  ('US consumer spending stalls even as inflation eases ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F0555ae3a-52ef-4603-91bb-5772d5501860.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...At one point, the S&P 500 down almost 3 per cent, before it ended 1.4 per cent lower.\n\nThe S&P 500 was up 0.3 per cent in midday dealings on Friday follow the release of the latest economic data....',
#   '2022-12-23T17:46:31+0000'),
#  ('US stocks waver as traders scrutinise fresh batch of economic data',
#   'None',
#   '...The benchmark S&P 500 added 0.3 per cent, erasing earlier losses, and the tech-heavy Nasdaq Composite declined 0.1 per cent in afternoon dealings on Friday....',
#   '2022-12-23T17:43:03+0000'),
#  ('Bonus cuts and job losses: Goldman’s painful new year',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Feff944a3-6886-4eed-b95e-5e9a541efcd5.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Goldman’s share price has also outperformed the benchmark S&P 500 index this year.\n\n“You’re going to struggle to see the bloom in that rose, but we accomplished a lot in 2022,” Waldron said....',
#   '2022-12-23T13:40:11+0000'),
#  ('Lufthansa: bonus plan is a navigational error by the board Premium\xa0content',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F72e94433-3964-4e47-a0f0-f19f6ec90fe3.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...These trade in line with peers at 12.6 times forward earnings, according to S&P Global....',
#   '2022-12-23T12:52:15+0000'),
#  ('European stocks waver ahead of US inflation data',
#   'None',
#   '...Thursday’s declines mean the S&P 500 and the Nasdaq Composite have tumbled 20 per cent and 33 per cent, respectively in 2022....',
#   '2022-12-23T10:42:15+0000'),
#  ('Bankman-Fried’s $250mn bail   ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fd1d2f12e-5440-4f41-86e3-587fa7d50db7.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 fell around 20 per cent and the bond market had a massive sell-off. But it looks like investors are wading back into debt....',
#   '2022-12-23T05:01:27+0000'),
#  ('Investing in 2023: Equities still offer value in tough times ',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fa663e5b6-a767-4b6c-91c4-e7bed70a3615.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...Equity markets have had a less dramatic year but end it in some disarray: while\xa0the FTSE 100 is broadly flat for 2022 so far, the S&P 500 is down by nearly 20 per cent and the Nikkei 225 by about 6 per cent...',
#   '2022-12-23T05:00:32+0000'),
#  ('Asian markets head lower as strong US data heightens interest rate expectations',
#   'None',
#   '...The S&P 500 closed 1.4 per cent lower. The tech-heavy Nasdaq Composite index slid 2.2 per cent....',
#   '2022-12-23T02:19:17+0000'),
#  ('What to watch in Asia today',
#   'None',
#   '...The S&P 500 closed 1.4 per cent lower and the Nasdaq Composite index slid 2.2 per cent....',
#   '2022-12-23T00:15:30+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US stocks knocked by weak earnings and unexpectedly strong economic data',
#   'None',
#   '...The S&P 500 closed 1.4 per cent lower, having fallen almost 3 per cent earlier. The tech-heavy Nasdaq Composite index slid 2.2 per cent....',
#   '2022-12-22T23:52:53+0000'),
#  ('US stocks slide as weak earnings and strong data weigh',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F83255125-0abf-4da6-9827-f5cab358b7ba.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...The S&P 500 closed 1.4 per cent lower, having fallen almost 3 per cent earlier. The tech-heavy Nasdaq Composite index slid 2.2 per cent....',
#   '2022-12-22T21:30:11+0000'),
#  ('US stocks knocked by weak earnings and unexpectedly strong economic data',
#   'None',
#   '...The S&P 500 closed 1.4 per cent lower, having fallen almost 3 per cent earlier. The tech-heavy Nasdaq Composite index slid 2.2 per cent....',
#   '2022-12-22T20:05:33+0000'),
#  ('Global stocks fall as strong US data support further monetary tightening',
#   'None',
#   '...The S&P 500 fell 1.3 per cent in early trade after US third-quarter GDP growth was revised higher to 3.2 per cent, from 2.9 per cent in November....',
#   '2022-12-22T15:59:12+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('US data signals economic resiliency amid Fed’s interest rate increases',
#   'None',
#   '...The S&P 500 was down 1.5 per cent in morning trading on Thursday. Before the release of the data, futures tipped the benchmark index to open about 0.3 per cent lower....',
#   '2022-12-22T15:04:04+0000'),
#  ('European stocks edge higher as dust settles after Japan policy move',
#   'None',
#   '...US stock futures indicated a further 0.2 per cent rise on Thursday for both the S&P 500 and the tech-heavy Nasdaq 100....',
#   '2022-12-22T09:41:13+0000'),
#  ('What to watch in Europe today',
#   'None',
#   '...On Wall Street, the S&P 500 and tech-heavy Nasdaq Composite each added 1.5 per cent on Wednesday....',
#   '2022-12-22T06:14:41+0000'),
#  ('Porsche and the decline of the German stock market',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2Fc9f59df8-6c8b-451b-bb46-34dd29098810.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...In the US, the S&P 500 index is up 42 per cent over the same period....',
#   '2022-12-22T05:00:18+0000'),
#  ('Chinese stocks push higher as Beijing stresses economic growth',
#   'None',
#   '...Thursday’s gains follow similar moves in the US, where the S&P 500 and Nasdaq Composite each added 1.5 per cent the day before, after receiving a boost early in the trading session when a report showed US...',
#   '2022-12-22T04:46:26+0000'),
#  ('Asian stocks rebound as US consumer sentiment report buoys global markets',
#   'None',
#   '...Hong Kong’s Hang Seng index and China’s CSI 300 gained 2 per cent and 0.7 per cent in early trading, while Japan’s Topix added 0.3 per cent\n\nThe S&P 500 and Nasdaq Composite each added 1.5 per cent on Wednesday...',
#   '2022-12-22T01:56:09+0000'),
#  ('What to watch in Asia today',
#   'None',
#   '...On Wall Street, the S&P 500 and tech-heavy Nasdaq Composite each added 1.5 per cent on Wednesday, getting a boost early in the trading session after a report showed US consumer confidence rebounded to its...',
#   '2022-12-22T00:33:50+0000'),
#  ('Global stocks rise as markets digest Bank of Japan policy change',
#   'None',
#   '...On Wall Street, the S&P 500 and tech-heavy Nasdaq Composite each added 1.5 per cent....',
#   '2022-12-21T23:45:34+0000'),
#  ('Global stocks rise as markets digest Bank of Japan policy change',
#   'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F4d3914f3-2737-4739-a3db-61b9f410f2fe.jpg?source=next&fit=scale-down&dpr=2&width=240',
#   '...On Wall Street, the S&P 500 and tech-heavy Nasdaq Composite each added 1.5 per cent....',
#   '2022-12-21T21:28:37+0000'),
#  ('None', 'None', 'None', 'None'),
#  ('Global stocks rise as markets digest Bank of Japan policy change',
#   'None',
#   '...On Wall Street, the S&P 500 and tech-heavy Nasdaq Composite each added 1.5 per cent....',
#   '2022-12-21T19:45:49+0000'),
#  ('US consumer confidence rebounds to eight-month high',
#   'None',
#   '...The consumer confidence data helped give stocks a boost on Wednesday, with the S&P 500 rallying following the release of the report to be 1.7 per cent higher in morning trading....',
#   '2022-12-21T16:11:05+0000'),
#  ...]

# %%
df = pd.DataFrame(NewsList, columns=('title', 'image', 'description', 'time'))
df
# Out:
#                                                   title  \
# 0     Wall Street stocks mixed as investors assess U...
# 1                        Fisking Moulding’s fulmination
# 2                                                  None
# 3           The market is up — narrowly Premium content
# 4     Wall Street stocks subdued after mixed earning...
# ...                                                 ...
# 1115  Unilever: slimming down ice-cream brands could...
# 1116  ExxonMobil announces $50bn buyback despite pol...
# 1117  Hong Kong stocks rally as investors eye plans ...
# 1118  Heavy selling of European equity ETFs reverses...
# 1119  UK businesses turn to employee-ownership at re...
#
#                                                   image  \
# 0     https://www.ft.com/__origami/service/image/v2/...
# 1     https://www.ft.com/__origami/service/image/v2/...
# 2                                                  None
# 3     https://www.ft.com/__origami/service/image/v2/...
# 4     https://www.ft.com/__origami/service/image/v2/...
# ...                                                 ...
# 1115  https://www.ft.com/__origami/service/image/v2/...
# 1116  https://www.ft.com/__origami/service/image/v2/...
# 1117                                               None
# 1118  https://www.ft.com/__origami/service/image/v2/...
# 1119  https://www.ft.com/__origami/service/image/v2/...
#
#                                             description  \
# 0     ...The S&P 500 was flat in afternoon trade in ...
# 1     ...That’s a lower proportion than the S&P 500,...
# 2                                                  None
# 3     ...The S&P 500 index has performed just fine s...
# 4     ...The S&P 500 closed up 0.1 per cent, with a ...
# ...                                                 ...
# 1115  ...Unilever is currently trading at 18 times e...
# 1116  ...The strategy has made Exxon among the marke...
# 1117  ...Contracts tracking Wall Street’s benchmark ...
# 1118  ...P 500 and 21 per cent slide in the MSCI Eme...
# 1119  ...Nearly 500 employee ownership trusts were s...
#
#                           time
# 0     2023-04-19T19:57:40+0000
# 1     2023-04-19T15:27:19+0000
# 2                         None
# 3     2023-04-19T05:30:36+0000
# 4     2023-04-18T20:29:58+0000
# ...                        ...
# 1115  2022-12-08T17:53:27+0000
# 1116  2022-12-08T16:43:17+0000
# 1117  2022-12-08T10:35:24+0000
# 1118  2022-12-08T05:00:49+0000
# 1119  2022-12-08T05:00:49+0000
#
# [1120 rows x 4 columns]

# %% [markdown]
# # Preprocessing

# %%
df[['date', 'time']] = df['time'].str.split('T', expand=True)

# %%
df['title&desc'] = df['title'] + ": " + df['description']

# %%
df.to_csv('FT_S&P500_rawdata.csv')

# %% [markdown]
# # Sentiment Analysis

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 76.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 89.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1

# %%
import torch
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
tokenizer = AutoTokenizer.from_pretrained("mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")
trainer = Trainer(model=model)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/933 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]

# %% [markdown]
# ## Title&Description Sentiment Analysis

# %%
file_name = "FT_S&P500_rawdata.csv"
text_column = "title&desc"

df_pred = pd.read_csv(file_name)
pred_texts = df_pred[text_column].astype('str').tolist()

# %%
class SimpleDataset:
    def __init__(self, tokenized_texts):
        self.tokenized_texts = tokenized_texts
    
    def __len__(self):
        return len(self.tokenized_texts["input_ids"])
    
    def __getitem__(self, idx):
        return {k: v[idx] for k, v in self.tokenized_texts.items()}

# %%
tokenized_texts = tokenizer(pred_texts,truncation=True,padding=True)
pred_dataset = SimpleDataset(tokenized_texts)
predictions = trainer.predict(pred_dataset)
preds = predictions.predictions.argmax(-1)
labels = pd.Series(preds).map(model.config.id2label)
scores = (np.exp(predictions[0])/np.exp(predictions[0]).sum(-1,keepdims=True)).max(1)

# %%
df_text_sentiment = pd.DataFrame(list(zip(pred_texts,preds,labels,scores)), columns=['text','pred','label','score'])
df_text_sentiment
# Out:
#                                                    text  pred     label  \
# 0     Wall Street stocks mixed as investors assess U...     2  positive
# 1     Fisking Moulding’s fulmination: ...That’s a lo...     0  negative
# 2                                            None: None     1   neutral
# 3     The market is up — narrowly Premium content: ....     2  positive
# 4     Wall Street stocks subdued after mixed earning...     0  negative
# ...                                                 ...   ...       ...
# 1115  Unilever: slimming down ice-cream brands could...     0  negative
# 1116  ExxonMobil announces $50bn buyback despite pol...     2  positive
# 1117  Hong Kong stocks rally as investors eye plans ...     2  positive
# 1118  Heavy selling of European equity ETFs reverses...     0  negative
# 1119  UK businesses turn to employee-ownership at re...     2  positive
#
#          score
# 0     0.540909
# 1     0.970179
# 2     0.999833
# 3     0.999714
# 4     0.998758
# ...        ...
# 1115  0.762752
# 1116  0.999709
# 1117  0.990453
# 1118  0.998711
# 1119  0.999673
#
# [1120 rows x 4 columns]

# %%
df['text_score'] = df_text_sentiment['pred']
df['text_label'] = df_text_sentiment['label']

# %% [markdown]
# ##Title Sentiment Analysis

# %%
file_name = "/content/FT_S&P500_rawdata.csv"
text_column = "title"

df_pred = pd.read_csv(file_name)
pred_texts = df_pred[text_column].astype('str').tolist()

# %%
class SimpleDataset:
    def __init__(self, tokenized_texts):
        self.tokenized_texts = tokenized_texts
    
    def __len__(self):
        return len(self.tokenized_texts["input_ids"])
    
    def __getitem__(self, idx):
        return {k: v[idx] for k, v in self.tokenized_texts.items()}

# %%
tokenized_texts = tokenizer(pred_texts,truncation=True,padding=True)
pred_dataset = SimpleDataset(tokenized_texts)
predictions = trainer.predict(pred_dataset)
preds = predictions.predictions.argmax(-1)
labels = pd.Series(preds).map(model.config.id2label)
scores = (np.exp(predictions[0])/np.exp(predictions[0]).sum(-1,keepdims=True)).max(1)

# %%
df_title_sentiment = pd.DataFrame(list(zip(pred_texts,preds,labels,scores)), columns=['text','pred','label','score'])
df_title_sentiment
# Out:
#                                                    text  pred     label  \
# 0     Wall Street stocks mixed as investors assess U...     1   neutral
# 1                        Fisking Moulding’s fulmination     1   neutral
# 2                                                  None     1   neutral
# 3           The market is up — narrowly Premium content     2  positive
# 4     Wall Street stocks subdued after mixed earning...     0  negative
# ...                                                 ...   ...       ...
# 1115  Unilever: slimming down ice-cream brands could...     2  positive
# 1116  ExxonMobil announces $50bn buyback despite pol...     2  positive
# 1117  Hong Kong stocks rally as investors eye plans ...     2  positive
# 1118  Heavy selling of European equity ETFs reverses...     0  negative
# 1119  UK businesses turn to employee-ownership at re...     2  positive
#
#          score
# 0     0.999285
# 1     0.999868
# 2     0.999841
# 3     0.991909
# 4     0.998676
# ...        ...
# 1115  0.954296
# 1116  0.999187
# 1117  0.998626
# 1118  0.983755
# 1119  0.775850
#
# [1120 rows x 4 columns]

# %%
df['title_score'] = df_title_sentiment['pred']
df['title_label'] = df_title_sentiment['label']

# %% [markdown]
# #Description Sentiment Analysis

# %%
file_name = "/content/FT_S&P500_rawdata.csv"
text_column = "description"

df_pred = pd.read_csv(file_name)
pred_texts = df_pred[text_column].astype('str').tolist()

# %%
tokenized_texts = tokenizer(pred_texts,truncation=True,padding=True)
pred_dataset = SimpleDataset(tokenized_texts)
predictions = trainer.predict(pred_dataset)
preds = predictions.predictions.argmax(-1)
labels = pd.Series(preds).map(model.config.id2label)
scores = (np.exp(predictions[0])/np.exp(predictions[0]).sum(-1,keepdims=True)).max(1)

# %%
df_description_sentiment = pd.DataFrame(list(zip(pred_texts,preds,labels,scores)), columns=['text','pred','label','score'])
df_description_sentiment
# Out:
#                                                    text  pred     label  \
# 0     ...The S&P 500 was flat in afternoon trade in ...     2  positive
# 1     ...That’s a lower proportion than the S&P 500,...     0  negative
# 2                                                  None     1   neutral
# 3     ...The S&P 500 index has performed just fine s...     2  positive
# 4     ...The S&P 500 closed up 0.1 per cent, with a ...     0  negative
# ...                                                 ...   ...       ...
# 1115  ...Unilever is currently trading at 18 times e...     1   neutral
# 1116  ...The strategy has made Exxon among the marke...     2  positive
# 1117  ...Contracts tracking Wall Street’s benchmark ...     1   neutral
# 1118  ...P 500 and 21 per cent slide in the MSCI Eme...     0  negative
# 1119  ...Nearly 500 employee ownership trusts were s...     2  positive
#
#          score
# 0     0.999648
# 1     0.986927
# 2     0.999841
# 3     0.999709
# 4     0.986746
# ...        ...
# 1115  0.999806
# 1116  0.999716
# 1117  0.679809
# 1118  0.998799
# 1119  0.999682
#
# [1120 rows x 4 columns]

# %%
df['description_score'] = df_description_sentiment['pred']
df['description_label'] = df_description_sentiment['label']

# %%
df.to_csv('FT_S&P500_sentiment.csv')

# %% [markdown]
# # Image to Text

# %%
df['image'] = df['image'].replace('width=240', 'width=1080', regex = True)

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]

# %%
import numpy as np
df['image_desc'] = np.nan

# %%
for index, link in enumerate(df['image']):
  if df['image'][index] != 'None':
    img_url = link
    raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')

    # conditional image captioning
    text = "a photography of"
    inputs = processor(raw_image, text, return_tensors="pt")

    out = model.generate(**inputs)
    #print(processor.decode(out[0], skip_special_tokens=True))
    # >>> a photography of a woman and her dog

    # unconditional image captioning
    inputs = processor(raw_image, return_tensors="pt")

    out = model.generate(**inputs)
    df['image_desc'][index] = processor.decode(out[0], skip_special_tokens=True)
    print(processor.decode(out[0], skip_special_tokens=True))
    #a woman sitting on the beach with her dog
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# <ipython-input-34-f30eb2729b32>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['image_desc'][index] = processor.decode(out[0], skip_special_tokens=True)
# the world map with a red background
# the logo of the hg company is seen on the side of a building in downtown
# a blue bull with a red background
# a street sign with a red background
# people look out over the city skyline from the sha shai observation tower in shanghai, china
# a street sign on a pole in the city
# a street sign with a red background
# the merk logo is seen on a wall in front of a building
# a glass door with a sign that says'closed '
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a city skyline with a red sky in the background
# a silhouette of a person walking past a credit suise logo
# a man in a helmet and a safety vest is working on a large metal object
# a man in a sweater is holding a cell
# smoke rises from the scene of a fire in the city of abu
# a woman walking down the street carrying a shopping bag
# a group of people sitting at tables writing
# a red background with a world map and a bar chart
# a man holding an umbrella walks past a store
# a man is standing in front of a white truck
# holiday inn express express
# the world map with a red background
# the logo of the hg company is seen on the side of a building in downtown
# a blue bull with a red background
# a street sign with a red background
# people look out over the city skyline from the sha shai observation tower in shanghai, china
# a street sign on a pole in the city
# a street sign with a red background
# the merk logo is seen on a wall in front of a building
# a glass door with a sign that says'closed '
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a city skyline with a red sky in the background
# a silhouette of a person walking past a credit suise logo
# a man in a helmet and a safety vest is working on a large metal object
# a man in a sweater is holding a cell
# smoke rises from the scene of a fire in the city of abu
# a woman walking down the street carrying a shopping bag
# a group of people sitting at tables writing
# a red background with a world map and a bar chart
# a man holding an umbrella walks past a store
# a man is standing in front of a white truck
# holiday inn express express
# a man riding a motorcycle down a street
# a street sign with a red background
# a red bus driving down a city street
# a pile of coins and a bunch of coins
# a man is putting a piece of fruit into a veg veg veg veg ve
# a display of colorful crocs
# a building with a statue on top of it
# a tall building
# the new crypt coin
# a street sign with a red background
# a woman in a hotel room holding a towel
# a man sitting on a bench with a paper bag over his head
# a plane is flying low over a field
# a red background with a white globe and a line graph
# a man in a factory working on a piece of metal
# a sunset behind the oil pumps
# microsoft headquarters in palo, california
# a mug with the words news briefing on it
# a mug with the words news briefing on it
# a city skyline with red and white squares
# two men sitting at a table with drinks
# a city skyline with a red sky in the background
# a close up of a computer processor
# a man walks past a bank in the financial district of frankfurt, germany, on january 26,
# a man in a suit sitting on a bench
# a man in a suit and tie standing next to a man in a suit
# a photo of two coins with a plane flying in the background
# a city skyline with red and white squares
# the logo for the company is shown in this illustration
# the logo of the us securities securities securities securities securities securities securities securities securities securities securities securities securities securities
# a well for oil
# a row of houses
# a blue bull with a red background
# a young boy with a backpack on his back
# a graphic of a pink flower with a graph graph
# the world map with a red background
# people walking across a crosswalk in front of a building
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a man in a suit
# a building with a sign that says cixi
# the supreme court and the supreme seal
# a mountain range
# a row of buildings
# a man walks past a svpvte office in tokyo
# a woman walks past a store with a large screen displaying a picture of a woman's face
# a sign that says oppec
# two men in suits and ties holding wine glasses
# a large fire is burning in the sky
# a woman with her eyes closed and her eyes closed
# a man wearing a beanie hat and a scarf
# a col of images of people working in a computer lab, a woman in a leather jacket and
# a statue of abraham sits in front of the u s capitol
# a person in blue gloves holding a spoon with a powder
# a man swinging a bat
# a large advertisement on a building
# a small street in the village of saint - martin
# a small plane flying through a cloudy sky
# a red sky
# a building with a sign that says first bank
# a man is walking down an escalator
# a swiss flag flying in the air
# two men in suits walking down a spiral staircase
# a man carrying a green container on his head
# a red background with a white globe and a line graph
# a man standing in front of a computer
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a man in a suit and tie talking
# a red background with a white globe and a line graph
# a person holding a phone with a logo on it
# the globe with a red background
# a police officer holding a gun
# three bottles of alcohol sitting on a shelf
# a man in a suit and tie is giving a thumbs
# a man in a suit and tie holding a tablet
# a red background with a white globe and a line graph
# a street sign with a red background
# a city with a castle in the background
# a woman with white hair
# a man sitting in a room with chairs
# a sign on a pole in front of a tall building
# a man walking past a building
# a red arrow pointing upward over a stock chart
# a man in a suit and tie speaking into a microphone
# a man holding two bags
# a man in a black shirt
# a man in a suit and tie sitting at a table
# a person wearing a black hoodie with a white writing on it
# a row of wind turbines
# a man standing in a warehouse with a large amount of white bags
# a red background with a white globe and squares
# a painting of a person walking on a beach
# a man in a suit and tie is giving a speech
# a man in a suit and tie with a red background
# a close up of a computer screen with a crypt symbol
# fed - chairman janet yelland testifies the fed - chief's role
# a man in a suit and tie with the united state logo
# vladimir putin and a train
# a person holding a cell phone with the logo of a financial authority
# a red background with a white globe and a line graph
# a sign that says first republic bank
# a man riding a bike past a sign for a public bank
# a red sky
# a man in a green jacket is looking out the window
# a street sign with a red background
# a man walking past a building with a sign that reads credit
# a building with a sign on top of it
# a man and woman standing in a courtroom
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a building with a sign that says u s
# two men in suits and ties standing next to each other men
# a disney logo on a blue plastic object
# a red background with a white globe and a line graph
# a woman standing in front of a window
# the federal building with a red arrow pointing upward
# a bit coin sitting on top of a computer keyboard
# a woman walking down the sidewalk
# a man in a suit and tie gestures
# the globe with a red background
# a building with a sign on top of it
# a glass building with the word bar on it
# a flag on a pole
# a large white pipe
# credit cards stacked on top of each other credit cards
# a sign on the side of a building that says charles's
# a man talking on a cell while another looks on
# a man walks past the entrance to the central bank of hong in hong
# a ve ve ve ve ve ve ve ve ve ve ve ve ve ve ve ve ve ve
# a swiss flag flying in front of a building
# a crowd of people standing in front of a gate
# a man in a suit and glasses speaking
# a man in a suit and tie standing next to a group of red storm troopers
# a statue of a bull
# a street sign with a red background
# a street sign with a red background
# a police officer walks past a storefront
# a cartoon character sitting at a desk with the capt that says, ` `''''
# a man in a suit and tie is speaking
# a car is parked in front of a parking meter
# a sign that reads fdic is hanging on a door
# a shadow of a person on a sign
# two men shaking hands in a room
# a smartphone with the svb logo on it
# a man sitting at a desk with a computer
# a man is standing outside of a bank of america
# a man in a factory working on a machine
# a man in a suit and tie standing in front of a sign
# a man in a suit and tie sitting at a table
# a man wearing glasses and a suit
# a man in a suit is handing another person a business card
# a woman with long hair
# a man with glasses and a suit jacket
# a man and woman standing in front of a giant head
# a man in a white hoodie is speaking
# a man in a black uniform
# a group of people walking across a bridge
# a man walking down a street in a white tank top
# a man in a gray shirt
# a mug with the words news briefing on it
# the logo of facebook and facebook are seen on a screen in this illustration taken from reuters
# a man in a suit and tie sitting in a chair
# three models in leather jackets and jackets
# a man in a suit and tie walking through a room
# a man in a suit and tie speaking into a microphone
# a group of people standing in front of a wall
# a woman in a suit running through a wave
# a street sign with a picture of a man on it
# a group of buses driving down a street
# a red background with a white globe and a line graph
# a chess game with the pieces in the middle
# a man in a construction uniform is standing next to a pile of wood
# two men in the jungle
# a mountain with a yellow arrow pointing up to the top
# a woman walking down a street in a city
# two men in suits
# a phone with the logo of the company on it
# a red background with a white globe and a line graph
# a bull statue stands in front of a stock market
# a model of a building
# a black suv parked in front of a building
# a large wave
# a man is checking his phone while a woman is standing next to him
# a blue and orange background with a stock chart
# a rolled dollar bill on a blue background
# a street sign with a red background
# a woman holding a black friday sale sign
# a white truck with a blue tail fin on it
# a street sign with a picture of a man on it
# a man wearing a suit
# a man in a suit and tie with a red and white sign
# a close up of a monkey with a blury background
# a street sign with a red background
# a circular sign on the side of a building
# a person is shown in front of a row of roundup deters
# a man walking in front of a large machine
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# the logo for the deutsche finance company
# the business of formula
# a woman sitting at a table with a microphone
# a red background with a white globe and a line graph
# a box of catalyn
# a woman is opening the door of her car
# a man in a red shirt is holding his head
# a man in a wheelchair with a woman
# a mug with the words news briefing on it
# a woman is opening the door of a car
# a man walking down a street past a building
# military soldiers with a military vehicle and a helicopter
# a man in a blue shirt and white hat working on a machine
# a man in a welding mask welding a piece of metal
# a field of yellow daffus
# a euro coin and a pile of money
# a man with a soccer ball in his mouth
# a man is shopping in a grocery store
# a red background with a white globe and squares
# a church in the middle of a town
# a graph with a dollar and a dollar on it
# a hot air balloon flying over a building
# a pile of money with the words'money'in the background
# a woman wearing a pink hat with the word forever written on it
# a red background with a white globe and a line graph
# a globe with a golden cross on it
# theresa may speaking at the conservative conference in london
# a man walking through a large room filled with lots of monitors
# a building with a red background and a red background
# a person in a black hood and a skull mask
# a sign that says intel
# coin with coin on top and coin on bottom
# two men standing on a beach with a dog
# a street sign with the words walls on it
# the new york stock exchange
# a man in a suit and tie standing on a roof
# a group of people holding flags and signs
# a woman with glasses on and a blue shirt
# a street sign with a red background
# a man walking past a home depot store
# a skull and crossbone on a chart
# a man in a white coat
# a woman in a red dress is walking by the water
# a man looking at a computer screen
# the logo for the deutsche finance company
# a man in a suit and tie with the words vanguard
# a woman in a striped sweater pointing at the camera
# a view of a city from a window
# a group of people riding bikes down a street
# a man in a suit and tie sitting in a chair
# a man in a suit and tie with the goldman logo on it
# a man is standing in front of a bunch of flowers
# the four images show the different buildings and the building
# a woman sitting at a table with a microphone
# a woman carrying a shopping bag on a city street
# a purple and white sign
# a man in a black jacket
# a man walks past the facade of the new york stock exchange building in new york, ny,
# a man in a suit and tie is gesturing
# a person picking grapes from a bin
# a man sitting at a desk with a computer
# a man walking down the sidewalk with a child
# a man riding a bike past a building
# two men sitting down
# people crossing the street
# a large tree in front of a building
# president joe bider speaks at a campaign event in washington
# a group of people working in a large store
# a man in a military uniform is sitting in the cockpit of a helicopter
# a statue of an angel with wings on it
# a man in a suit and tie speaking into microphones
# a mug with the words news briefing on it
# a man in a suit and tie is standing in front of an arrow
# a statue with a red and blue arrow on top
# a man in a store
# a woman looking at a bottle of milk
# a bald bald man
# a burger king sign is seen in this file photo
# people shopping in a supermarket
# a man in a suit and tie walking down a street
# a large open pit with a dirt road in the middle
# a bear walking in front of a stock chart
# containers are stacked at the port of los
# a construction site
# a man in a suit is looking at a computer
# a boat with a bunch of people on it
# a red arrow is seen in the middle of a city
# a man sitting in front of a computer monitor
# an oil rig and a man in a suit
# a man in a field with a tank in the background
# a man in a suit and tie is standing next to a curtain
# a close up of a business graph
# a mug with the words news briefing on it
# a woman is walking through a colorful pattern
# a sign with a picture of a truck and a sign with a picture of a truck
# a group of people standing in front of a building
# a man walks past the entrance to the bank of england in london
# a woman with a triangle and a triangle
# two people are standing on a sidewalk in front of a building
# a green arrow is seen on the screen of a smartphone
# a man in a suit and tie is holding a pair of glasses
# a man in a suit and tie sitting in a chair
# a man in a suit and tie sitting in a chair
# a man wearing glasses and a suit
# two men in suits and ties are standing next to each other men
# a city skyline
# a mug with the words news briefing on it
# a man in a suit and tie standing at a podium
# a man in a suit and tie speaking into a microphone
# a view of the capitol building in washington
# a sign on a building that says sorbi
# a man in a suit holding a mega mega mega mega mega mega mega mega mega mega mega mega
# a bald bald bald man in a suit
# a man in a suit is looking at a computer screen
# a box of public storage sits on the floor
# a silver truck parked on a road
# a man in a suit is standing outside a building
# people stand in front of a collapsed building
# a woman walking past a glass building
# a woman in a green jacket
# a man looking at a computer screen with a chart on it
# olives on a branch
# a woman pushing a shopping cart in a store
# a woman holding an umbrella
# two men sitting at a desk with multiple monitors
# a sign that says we hiring
# a man walking past a building with a sign on it
# a man walking past a sign that says we are hiring
# a man in a suit walking down a sidewalk
# an apple logo with the words alphabet a and an apple
# a sign that says adan cng
# the logo for the deutsche finance company
# a man in a white jacket and a white jacket standing in front of a wall of colorful signs
# a television screen showing a news report on the fox news
# a man in a suit and tie walking down a street
# a television screen shows the fox news on the floor
# the european union flag flies in the wind
# a man in a suit and tie with a red background
# a man in a helmet holding a marijuana and a bit coin
# a man in a suit and tie giving a speech
# a white truck with a green street sign on it
# a man in a suit and tie looking up
# a man with glasses and a suit jacket
# a clock on a stone building with a sign that reads fearless
# a man is shopping in a grocery store
# a man standing on a construction site with the sun setting in the background
# a red phone with a broken screen
# a woman walks past a burned vehicle in the town of st petersburg, russia, on march 23
# two people sitting at a table with a lamp
# a woman in a hospital room wearing a mask
# a close up of a sign on a building
# a green screen with the word snap on it
# a close up of a cell with the exomii logo on it
# a duck on a block of ice
# a gas station at night with a car passing by
# a man walks past a hua hua 5g smartphone during the launch of hua's flagship phone
# a group of people standing in front of a plane
# a building with a statue on top of it
# a laptop with a blue intel chip on it
# a cartoon drawing of a man and woman with a dog
# a man in a white coat and blue gloves is working on a metal cone
# a car is parked in front of a gas station
# a man and woman walking down a sidewalk carrying bags
# a man in a suit and tie with glasses
# a large balloon with a whale on it
# a man with glasses is sitting in front of a computer
# a man in a suit and tie standing at a podium
# two men in front of a castle
# a chen sign on a wall
# stock market trading chart on digital screen
# a black and white photo of a city street with a red and blue line
# two men working on a house under construction
# a group of people standing in front of a building
# credit cards stacked on top of each other credit cards
# the headquarters of the harvard school of medicine
# a tesla logo is seen on a store window
# a series of six different colored graphs
# the logo for the petroleum company, with oil pumps in the background
# donald trump at the white house correspondent awards
# a cartoon of benjamin franklin with bubbles around him
# a che che che che che che che che che che che che che che che che che che
# a blue and yellow background with a picture of a man in a suit
# two men in suits are looking at a screen
# a man in a suit looking at a monitor
# a plane taking off
# a little girl sitting at a table with a plant in front of her
# a fire and water explosion in the dark
# a person holding a sign with a person in the background
# a tank is driving through the dirt
# a street sign on a pole in the city
# a painting of a leopard and a leopard sitting on a couch
# a man in a sweater vest is standing in front of a computer
# a man in a black jacket is looking at a tablet
# a man walking past a rayton store
# a man in a red shirt and green hat
# three men holding up speech bubbles with the words push, push, and then
# a group of people walking down a sidewalk
# a man in a white suit and a white hat is welding
# a large solar farm in the middle of the country
# a glass building with a sign on it
# a woman with blonde hair and a black shirt
# a hot tub in a rooftop pool with a view of the city skyline
# a person holding a dollar bill in their hands
# a trader looks at the screen of a stock market
# a man in a suit and tie speaking
# a couple of people walking down a dirt road
# happy birthday to you happy birthday to you happy birthday to you happy birthday to you happy birthday to
# a collage of a house, a man working on a machine and a man working on a
# a street sign with a flag hanging from the side
# a group of people walking down a street holding signs
# a pair of scissors in a man's hand
# a screenshot of a person standing on a pier at night
# a street sign on a pole in the city
# a woman with white hair
# a woman with long lashes and a mascara brush
# a man in a suit and tie sitting in a chair
# a man in a blue shirt is looking at a computer
# a close up of a man wearing glasses
# a woman sitting in a chair with a bottle of water
# a large brick building
# a cartoon of a man drinking champagne while another man watches
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a bull is walking on a sidewalk in front of a city
# a street sign on a wall with a building in the background
# a person is using a gas pump
# a blue bull with a red background
# two men in suits and ties, one is looking up at the camera
# a man in an orange shirt
# a man in a suit is looking at a computer screen
# a book cover with a picture of a city
# a man standing on a sidewalk in front of a construction site
# a street sign with a picture of a man on it
# a street sign with a picture of a man on it
# a man sitting on a chair with red and blue lines
# a large stone statue
# a group of people sitting at a table in a room
# a city with tall buildings
# oil prices fall as us oil prices fall
# a man walking past a building with a sign on it
# a group of people working on a tree
# a window with a view
# people walking in front of a large wall with a painting of corals
# a bridge with a chinese flag over it
# a green and red background with a pattern of white and red lines
# a woman standing on a stage with a microphone and a crowd of people
# people walk past the u s federal building in washington
# a man in a suit and tie with a star
# a woman wearing a face mask walks past a bank of america sign
# a bitcoin coin with the words bitcoin on it
# a man in a blue shirt
# the 888 holdings logo is seen on a smartphone in this photo illustration taken from reuters
# a large boat in the water
# a bunch of miniature figs
# a woman is shopping in a store with a sign
# a pile of hundred dollar bills
# two men in front of a castle
# a group of people playing baseball in a parking lot
# a man riding a motorcycle down a street
# two people standing in front of a wall with a large screen
# a building with a lot of lights on it
# a sign on a building that says blackrock
# a man walks past the wall street entrance to the new york stock exchange in new york, new
# a man sitting at a desk with a laptop
# the federal reserve sign on the federal reserve building
# a person holding a phone with the prias logo on it
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a man in a suit and tie holding a tablet
# a sign that says astraneaa
# a man walking across a large body of water
# a sign that says astraza on it
# a statue of a bear with a red background
# a man in a suit and tie is speaking
# apple logo with the words apple and a red apple
# a woman walking past a store window with a red sign
# apple logo with a red and blue background
# a red car is on the street
# a man wearing sunglasses and a black shirt
# traders look at their phones as they work on the floor of the new york stock exchange in new
# a large glass window
# a man in a hard hat and hard hat standing on a large pipe
# tesla's new electric car is a real thing
# a man walking down a sidewalk with a backpack
# a woman in glasses and a blue sweater stands in front of a colorful forest
# a man with a beard and a beard standing in front of a white wall
# a man in a suit and tie is covering his face
# a man in a suit standing in front of a wall of monitors
# a statue of an angel on top of a building
# a large red building
# a bus is parked in front of a construction site
# a futuristic car is parked in a garage
# the spr logo
# a group of people sitting around a table with laptops
# a man sitting in front of a computer
# a pink and purple logo with a pink triangle in the middle
# a man in a suit and tie waves to the crowd
# tesla's new electric vehicle is shown at the company's plant in fremont, calif
# a woman looking through binoculars
# a street sign with a picture of a man on it
# a yellow alarm clock with the words behind it
# a car with a dashboard and a steering
# a colorful illustration of a woman with a guitar
# tesla's electric car charging station
# a large passenger jet flying through a blue sky
# a stop sign is attached to a building
# a painting of a girl with a pearl
# a woman in a striped sweater pointing at the camera
# people walk past the christmas tree in front of the bi biadle hotel in brussels, belgium
# a col of a building with a sign and a sign that says blackrock
# a woman in a blue jacket
# a reflection of a building
# a man working on a motorcycle in a factory
# two men in protective gear working on a piece of metal
# a large american flag is on a building
# the three men are standing in front of a black background
# a man walks past the new york stock exchange building in new york, new york, tuesday,
# a group of people walking down a street
# a group of people with the words 2021
# a woman walking down the street carrying shopping bags
# a group of people standing around a luggage carousel
# a man in a hard hat and hard hat looking at a train
# a woman in a helmet and a map
# a man in a suit and tie standing on a sidewalk
# a group of people walking along a river
# a large field of wheat
# a man walks past a logo of the company at the company's headquarters in tokyo, japan
# a blue sign with the word southwest airlines
# a man in a yellow jacket and blue helmet walks along a road
# people wearing masks walk through a crowded airport
# aerial view of the city of wuzhou, china
# a man walking past a stock exchange
# a man riding a bike down a path in a park
# a red car parked in a parking lot
# a building with a clock on the top of it
# a tree with no leaves
# a woman in a costume
# a man in a suit and tie standing in front of a blue background with the words gom
# a row of airplanes parked on a runway
# a mug with the words news briefing on it
# a col of people in suits and ties
# the new york stock exchange building in new york, ny
# a man in a suit and tie holding a paper airplane
# a man in a suit and tie walking down a street
# twitter logo on a phone
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a man wearing a suit
# a sign on a car
# a person filling gas into a car
# a bunch of flowers
# a street sign with a red background
# a man walks past the new york stock exchange building in new york, new york, on monday
# a man holding a dog in front of a pile of money
# a street sign with a picture of a man on it
# a man looks at a stock market board
# a large fire is coming from a chimney
# the federal reserve logo on the wall of the federal reserve building
# the european central bank headquarters in frankfurt
# a man in a suit and tie is standing in front of a purple background
# two men sitting at a table with a colorful background
# a man in a suit and tie standing next to a snowman
# a car being assembled in a factory
# a woman in a white coat
# a man in a protective suit is being wheeled by a medical worker
# the cast of the tv series of the show, with the caption of the cast of the
# a mug with the words news briefing on it
# a row of houses
# a satellite satellite is seen in this image from the north korean space agency
# traders work on the floor of the new york stock exchange in new york, new york, thursday
# a fire is lit in the air near a fire hydra
# a man in a suit
# a man in a suit and tie with a red background
# the logo for the deutsche finance company
# a man in a wheelchair is covered up by a protective suit
# the white house in washington
# the white house in washington
# a sign on a building
# jp morgan chase chase chase chase chase chase chase chase chase chase chase chase chase chase chase chase chase
# a man standing on top of stacks of coins
# a man in a suit and mask holding a tablet
# the logo for the deutsche finance company
# a christmas tree with ornaments and decorations
# a man in a suit and tie with glasses
# a man in a suit and tie is holding a pair of glasses
# a woman in a grocery aisle looking at items
# a coin with the word wall street on it
# a statue of an eagle on the side of a building
# a large ship in the water
# a man in a suit and tie speaking into a microphone
# wallpapers wallpapers wallpapers wallpapers wallpapers wallpapers wall
# a man in a blue sweater is speaking
# a statue of a man with a sword on a pedestal
# the sign for the mgm resort in las
# a man in a suit and tie sitting in a chair
# metro bank sign
# a man in a black shirt is making a face
# singapore skyline at night
# a group of people holding signs and flags
# a group of women in white robes sitting on the ground
# the new york stock exchange building with an american flag on the facade
# the logo for the deutsche finance company
# a man walking up a flight
# a large ship in the water
# a man looks at an electronic board displaying stock information at the stock exchange in hong
# the seal of the us securities office building
# a street sign on a wall with a building in the background
# a person in a mask and gloves holding three cups of yoo yoo yoo yoo
# a blue car parked in front of a gas station
# a man and woman walking in the rain with an umbrella
# a man in a blue shirt is smiling

# %%
df['image_desc'] = df['image_desc'].replace(np.nan, 'np.nan')

# %%
df['content'] = '(' + df['image_desc'] + '.) ' + df['title'] + ': ' + df['description']

# %%
df.to_csv('FT_S&P500_imagedesc.csv')

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
tokenizer = AutoTokenizer.from_pretrained("mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")
trainer = Trainer(model=model)

# %%
file_name = "FT_S&P500_imagedesc.csv"
text_column = "content"

df_pred = pd.read_csv(file_name)
pred_texts = df_pred[text_column].astype('str').tolist()

# %%
class SimpleDataset:
    def __init__(self, tokenized_texts):
        self.tokenized_texts = tokenized_texts
    
    def __len__(self):
        return len(self.tokenized_texts["input_ids"])
    
    def __getitem__(self, idx):
        return {k: v[idx] for k, v in self.tokenized_texts.items()}

# %%
tokenized_texts = tokenizer(pred_texts,truncation=True,padding=True)
pred_dataset = SimpleDataset(tokenized_texts)
predictions = trainer.predict(pred_dataset)
preds = predictions.predictions.argmax(-1)
labels = pd.Series(preds).map(model.config.id2label)
scores = (np.exp(predictions[0])/np.exp(predictions[0]).sum(-1,keepdims=True)).max(1)

# %%
df_content_sentiment = pd.DataFrame(list(zip(pred_texts,preds,labels,scores)), columns=['text','pred','label','score'])
df_content_sentiment
# Out:
#                                                    text  pred     label  \
# 0     (the world map with a red background.) Wall St...     2  positive
# 1     (the logo of the hg company is seen on the sid...     0  negative
# 2                                  (np.nan.) None: None     1   neutral
# 3     (a blue bull with a red background.) The marke...     2  positive
# 4     (a street sign with a red background.) Wall St...     0  negative
# ...                                                 ...   ...       ...
# 1115  (a person in a mask and gloves holding three c...     2  positive
# 1116  (a blue car parked in front of a gas station.)...     2  positive
# 1117  (np.nan.) Hong Kong stocks rally as investors ...     2  positive
# 1118  (a man and woman walking in the rain with an u...     0  negative
# 1119  (a man in a blue shirt is smiling.) UK busines...     2  positive
#
#          score
# 0     0.993402
# 1     0.928379
# 2     0.999857
# 3     0.999718
# 4     0.998731
# ...        ...
# 1115  0.852503
# 1116  0.999687
# 1117  0.996877
# 1118  0.998703
# 1119  0.999663
#
# [1120 rows x 4 columns]

# %%
df['content_score'] = df_content_sentiment['pred']
df['content_label'] = df_content_sentiment['label']

# %%
df.to_csv('FT_S&P500_sentiment.csv')

# %% [markdown]
# # Face Analysis

# %%
for index, link in enumerate(df['image']):
  if df['image'][index] != 'None':
    with open(f'/content/FT_SP500/{index}.png', 'wb') as f:
        r = requests.get(link).content
        f.write(r)

# %%
# !zip -r /content/FT_SP500.zip /content/FT_SP500
# Out:
#   adding: content/FT_SP500/ (stored 0%)
#   adding: content/FT_SP500/648.png (deflated 1%)
#   adding: content/FT_SP500/1047.png (deflated 8%)
#   adding: content/FT_SP500/878.png (deflated 1%)
#   adding: content/FT_SP500/491.png (deflated 2%)
#   adding: content/FT_SP500/1091.png (deflated 4%)
#   adding: content/FT_SP500/542.png (deflated 3%)
#   adding: content/FT_SP500/458.png (deflated 1%)
#   adding: content/FT_SP500/1065.png (deflated 3%)
#   adding: content/FT_SP500/688.png (deflated 2%)
#   adding: content/FT_SP500/444.png (deflated 1%)
#   adding: content/FT_SP500/182.png (deflated 6%)
#   adding: content/FT_SP500/972.png (deflated 2%)
#   adding: content/FT_SP500/208.png (deflated 2%)
#   adding: content/FT_SP500/971.png (deflated 6%)
#   adding: content/FT_SP500/722.png (deflated 4%)
#   adding: content/FT_SP500/524.png (deflated 1%)
#   adding: content/FT_SP500/809.png (deflated 5%)
#   adding: content/FT_SP500/36.png (deflated 25%)
#   adding: content/FT_SP500/309.png (deflated 25%)
#   adding: content/FT_SP500/199.png (deflated 1%)
#   adding: content/FT_SP500/956.png (deflated 3%)
#   adding: content/FT_SP500/469.png (deflated 4%)
#   adding: content/FT_SP500/161.png (deflated 2%)
#   adding: content/FT_SP500/442.png (deflated 1%)
#   adding: content/FT_SP500/361.png (deflated 1%)
#   adding: content/FT_SP500/732.png (deflated 3%)
#   adding: content/FT_SP500/31.png (deflated 1%)
#   adding: content/FT_SP500/70.png (deflated 1%)
#   adding: content/FT_SP500/108.png (deflated 4%)
#   adding: content/FT_SP500/823.png (deflated 0%)
#   adding: content/FT_SP500/874.png (deflated 2%)
#   adding: content/FT_SP500/54.png (deflated 2%)
#   adding: content/FT_SP500/960.png (deflated 2%)
#   adding: content/FT_SP500/322.png (deflated 4%)
#   adding: content/FT_SP500/543.png (deflated 0%)
#   adding: content/FT_SP500/127.png (deflated 4%)
#   adding: content/FT_SP500/356.png (deflated 5%)
#   adding: content/FT_SP500/1006.png (deflated 2%)
#   adding: content/FT_SP500/720.png (deflated 1%)
#   adding: content/FT_SP500/1083.png (deflated 1%)
#   adding: content/FT_SP500/344.png (deflated 2%)
#   adding: content/FT_SP500/796.png (deflated 3%)
#   adding: content/FT_SP500/731.png (deflated 5%)
#   adding: content/FT_SP500/335.png (deflated 6%)
#   adding: content/FT_SP500/130.png (deflated 1%)
#   adding: content/FT_SP500/784.png (deflated 4%)
#   adding: content/FT_SP500/778.png (deflated 2%)
#   adding: content/FT_SP500/833.png (deflated 9%)
#   adding: content/FT_SP500/1029.png (deflated 1%)
#   adding: content/FT_SP500/625.png (deflated 2%)
#   adding: content/FT_SP500/212.png (deflated 3%)
#   adding: content/FT_SP500/98.png (deflated 4%)
#   adding: content/FT_SP500/624.png (deflated 4%)
#   adding: content/FT_SP500/1030.png (deflated 2%)
#   adding: content/FT_SP500/1107.png (deflated 4%)
#   adding: content/FT_SP500/103.png (deflated 1%)
#   adding: content/FT_SP500/799.png (deflated 6%)
#   adding: content/FT_SP500/354.png (deflated 2%)
#   adding: content/FT_SP500/818.png (deflated 5%)
#   adding: content/FT_SP500/99.png (deflated 3%)
#   adding: content/FT_SP500/485.png (deflated 7%)
#   adding: content/FT_SP500/743.png (deflated 3%)
#   adding: content/FT_SP500/973.png (deflated 1%)
#   adding: content/FT_SP500/398.png (deflated 24%)
#   adding: content/FT_SP500/357.png (deflated 5%)
#   adding: content/FT_SP500/694.png (deflated 2%)
#   adding: content/FT_SP500/683.png (deflated 2%)
#   adding: content/FT_SP500/433.png (deflated 2%)
#   adding: content/FT_SP500/162.png (deflated 2%)
#   adding: content/FT_SP500/504.png (deflated 1%)
#   adding: content/FT_SP500/984.png (deflated 1%)
#   adding: content/FT_SP500/531.png (deflated 1%)
#   adding: content/FT_SP500/475.png (deflated 11%)
#   adding: content/FT_SP500/568.png (deflated 3%)
#   adding: content/FT_SP500/873.png (deflated 4%)
#   adding: content/FT_SP500/919.png (deflated 12%)
#   adding: content/FT_SP500/1102.png (deflated 0%)
#   adding: content/FT_SP500/158.png (deflated 1%)
#   adding: content/FT_SP500/1014.png (deflated 0%)
#   adding: content/FT_SP500/420.png (deflated 1%)
#   adding: content/FT_SP500/415.png (deflated 2%)
#   adding: content/FT_SP500/518.png (deflated 1%)
#   adding: content/FT_SP500/1023.png (deflated 0%)
#   adding: content/FT_SP500/907.png (deflated 2%)
#   adding: content/FT_SP500/484.png (deflated 2%)
#   adding: content/FT_SP500/490.png (deflated 1%)
#   adding: content/FT_SP500/604.png (deflated 3%)
#   adding: content/FT_SP500/588.png (deflated 2%)
#   adding: content/FT_SP500/326.png (deflated 3%)
#   adding: content/FT_SP500/547.png (deflated 1%)
#   adding: content/FT_SP500/501.png (deflated 3%)
#   adding: content/FT_SP500/1116.png (deflated 2%)
#   adding: content/FT_SP500/69.png (deflated 1%)
#   adding: content/FT_SP500/880.png (deflated 11%)
#   adding: content/FT_SP500/200.png (deflated 2%)
#   adding: content/FT_SP500/644.png (deflated 10%)
#   adding: content/FT_SP500/858.png (deflated 2%)
#   adding: content/FT_SP500/19.png (deflated 3%)
#   adding: content/FT_SP500/613.png (deflated 3%)
#   adding: content/FT_SP500/1028.png (deflated 1%)
#   adding: content/FT_SP500/1022.png (deflated 7%)
#   adding: content/FT_SP500/286.png (deflated 2%)
#   adding: content/FT_SP500/965.png (deflated 0%)
#   adding: content/FT_SP500/379.png (deflated 3%)
#   adding: content/FT_SP500/51.png (deflated 3%)
#   adding: content/FT_SP500/705.png (deflated 3%)
#   adding: content/FT_SP500/337.png (deflated 8%)
#   adding: content/FT_SP500/417.png (deflated 4%)
#   adding: content/FT_SP500/748.png (deflated 1%)
#   adding: content/FT_SP500/680.png (deflated 12%)
#   adding: content/FT_SP500/311.png (deflated 2%)
#   adding: content/FT_SP500/866.png (deflated 7%)
#   adding: content/FT_SP500/1051.png (deflated 2%)
#   adding: content/FT_SP500/275.png (deflated 4%)
#   adding: content/FT_SP500/434.png (deflated 2%)
#   adding: content/FT_SP500/828.png (deflated 4%)
#   adding: content/FT_SP500/822.png (deflated 2%)
#   adding: content/FT_SP500/380.png (deflated 1%)
#   adding: content/FT_SP500/544.png (deflated 1%)
#   adding: content/FT_SP500/654.png (deflated 3%)
#   adding: content/FT_SP500/109.png (deflated 2%)
#   adding: content/FT_SP500/921.png (deflated 10%)
#   adding: content/FT_SP500/181.png (deflated 2%)
#   adding: content/FT_SP500/184.png (deflated 1%)
#   adding: content/FT_SP500/154.png (deflated 1%)
#   adding: content/FT_SP500/391.png (deflated 1%)
#   adding: content/FT_SP500/453.png (deflated 5%)
#   adding: content/FT_SP500/9.png (deflated 1%)
#   adding: content/FT_SP500/432.png (deflated 36%)
#   adding: content/FT_SP500/1118.png (deflated 4%)
#   adding: content/FT_SP500/192.png (deflated 3%)
#   adding: content/FT_SP500/289.png (deflated 4%)
#   adding: content/FT_SP500/508.png (deflated 11%)
#   adding: content/FT_SP500/616.png (deflated 1%)
#   adding: content/FT_SP500/670.png (deflated 4%)
#   adding: content/FT_SP500/634.png (deflated 2%)
#   adding: content/FT_SP500/388.png (deflated 2%)
#   adding: content/FT_SP500/589.png (deflated 2%)
#   adding: content/FT_SP500/1005.png (deflated 1%)
#   adding: content/FT_SP500/1076.png (deflated 6%)
#   adding: content/FT_SP500/939.png (deflated 7%)
#   adding: content/FT_SP500/608.png (deflated 0%)
#   adding: content/FT_SP500/265.png (deflated 1%)
#   adding: content/FT_SP500/1064.png (deflated 6%)
#   adding: content/FT_SP500/1073.png (deflated 4%)
#   adding: content/FT_SP500/436.png (deflated 3%)
#   adding: content/FT_SP500/160.png (deflated 1%)
#   adding: content/FT_SP500/148.png (deflated 5%)
#   adding: content/FT_SP500/143.png (deflated 5%)
#   adding: content/FT_SP500/841.png (deflated 3%)
#   adding: content/FT_SP500/65.png (deflated 5%)
#   adding: content/FT_SP500/220.png (deflated 35%)
#   adding: content/FT_SP500/44.png (deflated 3%)
#   adding: content/FT_SP500/1067.png (deflated 2%)
#   adding: content/FT_SP500/502.png (deflated 2%)
#   adding: content/FT_SP500/150.png (deflated 2%)
#   adding: content/FT_SP500/401.png (deflated 3%)
#   adding: content/FT_SP500/1055.png (deflated 3%)
#   adding: content/FT_SP500/925.png (deflated 8%)
#   adding: content/FT_SP500/193.png (deflated 3%)
#   adding: content/FT_SP500/797.png (deflated 1%)
#   adding: content/FT_SP500/652.png (deflated 2%)
#   adding: content/FT_SP500/946.png (deflated 1%)
#   adding: content/FT_SP500/669.png (deflated 3%)
#   adding: content/FT_SP500/615.png (deflated 2%)
#   adding: content/FT_SP500/777.png (deflated 2%)
#   adding: content/FT_SP500/951.png (deflated 0%)
#   adding: content/FT_SP500/251.png (deflated 5%)
#   adding: content/FT_SP500/553.png (deflated 2%)
#   adding: content/FT_SP500/933.png (deflated 5%)
#   adding: content/FT_SP500/173.png (deflated 32%)
#   adding: content/FT_SP500/709.png (deflated 2%)
#   adding: content/FT_SP500/462.png (deflated 13%)
#   adding: content/FT_SP500/888.png (deflated 1%)
#   adding: content/FT_SP500/617.png (deflated 1%)
#   adding: content/FT_SP500/1110.png (deflated 3%)
#   adding: content/FT_SP500/294.png (deflated 11%)
#   adding: content/FT_SP500/804.png (deflated 6%)
#   adding: content/FT_SP500/963.png (deflated 3%)
#   adding: content/FT_SP500/406.png (deflated 3%)
#   adding: content/FT_SP500/826.png (deflated 3%)
#   adding: content/FT_SP500/1050.png (deflated 1%)
#   adding: content/FT_SP500/881.png (deflated 1%)
#   adding: content/FT_SP500/0.png (deflated 30%)
#   adding: content/FT_SP500/764.png (deflated 3%)
#   adding: content/FT_SP500/774.png (deflated 3%)
#   adding: content/FT_SP500/426.png (deflated 32%)
#   adding: content/FT_SP500/447.png (deflated 0%)
#   adding: content/FT_SP500/500.png (deflated 5%)
#   adding: content/FT_SP500/84.png (deflated 2%)
#   adding: content/FT_SP500/1078.png (deflated 3%)
#   adding: content/FT_SP500/163.png (deflated 6%)
#   adding: content/FT_SP500/6.png (deflated 3%)
#   adding: content/FT_SP500/578.png (deflated 2%)
#   adding: content/FT_SP500/516.png (deflated 1%)
#   adding: content/FT_SP500/280.png (deflated 2%)
#   adding: content/FT_SP500/767.png (deflated 1%)
#   adding: content/FT_SP500/87.png (deflated 36%)
#   adding: content/FT_SP500/708.png (deflated 1%)
#   adding: content/FT_SP500/117.png (deflated 9%)
#   adding: content/FT_SP500/402.png (deflated 4%)
#   adding: content/FT_SP500/319.png (deflated 2%)
#   adding: content/FT_SP500/664.png (deflated 5%)
#   adding: content/FT_SP500/8.png (deflated 25%)
#   adding: content/FT_SP500/844.png (deflated 1%)
#   adding: content/FT_SP500/270.png (deflated 1%)
#   adding: content/FT_SP500/891.png (deflated 2%)
#   adding: content/FT_SP500/13.png (deflated 1%)
#   adding: content/FT_SP500/92.png (deflated 8%)
#   adding: content/FT_SP500/1119.png (deflated 4%)
#   adding: content/FT_SP500/1003.png (deflated 2%)
#   adding: content/FT_SP500/225.png (deflated 1%)
#   adding: content/FT_SP500/214.png (deflated 1%)
#   adding: content/FT_SP500/957.png (deflated 3%)
#   adding: content/FT_SP500/1024.png (deflated 2%)
#   adding: content/FT_SP500/949.png (deflated 2%)
#   adding: content/FT_SP500/5.png (deflated 3%)
#   adding: content/FT_SP500/950.png (deflated 3%)
#   adding: content/FT_SP500/264.png (deflated 8%)
#   adding: content/FT_SP500/167.png (deflated 1%)
#   adding: content/FT_SP500/279.png (deflated 2%)
#   adding: content/FT_SP500/121.png (deflated 2%)
#   adding: content/FT_SP500/47.png (deflated 3%)
#   adding: content/FT_SP500/456.png (deflated 1%)
#   adding: content/FT_SP500/49.png (deflated 1%)
#   adding: content/FT_SP500/277.png (deflated 1%)
#   adding: content/FT_SP500/392.png (deflated 1%)
#   adding: content/FT_SP500/204.png (deflated 2%)
#   adding: content/FT_SP500/145.png (deflated 5%)
#   adding: content/FT_SP500/1061.png (deflated 2%)
#   adding: content/FT_SP500/1095.png (deflated 9%)
#   adding: content/FT_SP500/742.png (deflated 4%)
#   adding: content/FT_SP500/869.png (deflated 2%)
#   adding: content/FT_SP500/1045.png (deflated 2%)
#   adding: content/FT_SP500/459.png (deflated 3%)
#   adding: content/FT_SP500/124.png (deflated 2%)
#   adding: content/FT_SP500/682.png (deflated 6%)
#   adding: content/FT_SP500/274.png (deflated 35%)
#   adding: content/FT_SP500/369.png (deflated 5%)
#   adding: content/FT_SP500/715.png (deflated 3%)
#   adding: content/FT_SP500/460.png (deflated 3%)
#   adding: content/FT_SP500/690.png (deflated 4%)
#   adding: content/FT_SP500/853.png (deflated 1%)
#   adding: content/FT_SP500/877.png (deflated 6%)
#   adding: content/FT_SP500/21.png (deflated 1%)
#   adding: content/FT_SP500/805.png (deflated 2%)
#   adding: content/FT_SP500/520.png (deflated 1%)
#   adding: content/FT_SP500/263.png (deflated 32%)
#   adding: content/FT_SP500/991.png (deflated 2%)
#   adding: content/FT_SP500/76.png (deflated 24%)
#   adding: content/FT_SP500/22.png (deflated 30%)
#   adding: content/FT_SP500/81.png (deflated 14%)
#   adding: content/FT_SP500/88.png (deflated 35%)
#   adding: content/FT_SP500/532.png (deflated 7%)
#   adding: content/FT_SP500/821.png (deflated 2%)
#   adding: content/FT_SP500/737.png (deflated 1%)
#   adding: content/FT_SP500/738.png (deflated 2%)
#   adding: content/FT_SP500/1090.png (deflated 1%)
#   adding: content/FT_SP500/756.png (deflated 1%)
#   adding: content/FT_SP500/894.png (deflated 0%)
#   adding: content/FT_SP500/195.png (deflated 1%)
#   adding: content/FT_SP500/626.png (deflated 2%)
#   adding: content/FT_SP500/976.png (deflated 4%)
#   adding: content/FT_SP500/15.png (deflated 6%)
#   adding: content/FT_SP500/255.png (deflated 0%)
#   adding: content/FT_SP500/555.png (deflated 11%)
#   adding: content/FT_SP500/519.png (deflated 4%)
#   adding: content/FT_SP500/149.png (deflated 6%)
#   adding: content/FT_SP500/526.png (deflated 36%)
#   adding: content/FT_SP500/900.png (deflated 1%)
#   adding: content/FT_SP500/244.png (deflated 1%)
#   adding: content/FT_SP500/537.png (deflated 2%)
#   adding: content/FT_SP500/247.png (deflated 3%)
#   adding: content/FT_SP500/979.png (deflated 8%)
#   adding: content/FT_SP500/789.png (deflated 1%)
#   adding: content/FT_SP500/464.png (deflated 1%)
#   adding: content/FT_SP500/1108.png (deflated 3%)
#   adding: content/FT_SP500/927.png (deflated 4%)
#   adding: content/FT_SP500/168.png (deflated 1%)
#   adding: content/FT_SP500/845.png (deflated 6%)
#   adding: content/FT_SP500/250.png (deflated 2%)
#   adding: content/FT_SP500/768.png (deflated 4%)
#   adding: content/FT_SP500/46.png (deflated 5%)
#   adding: content/FT_SP500/29.png (deflated 18%)
#   adding: content/FT_SP500/641.png (deflated 4%)
#   adding: content/FT_SP500/439.png (deflated 2%)
#   adding: content/FT_SP500/816.png (deflated 1%)
#   adding: content/FT_SP500/376.png (deflated 1%)
#   adding: content/FT_SP500/714.png (deflated 2%)
#   adding: content/FT_SP500/1077.png (deflated 2%)
#   adding: content/FT_SP500/739.png (deflated 4%)
#   adding: content/FT_SP500/372.png (deflated 32%)
#   adding: content/FT_SP500/514.png (deflated 2%)
#   adding: content/FT_SP500/37.png (deflated 1%)
#   adding: content/FT_SP500/488.png (deflated 1%)
#   adding: content/FT_SP500/457.png (deflated 1%)
#   adding: content/FT_SP500/138.png (deflated 5%)
#   adding: content/FT_SP500/443.png (deflated 30%)
#   adding: content/FT_SP500/1.png (deflated 18%)
#   adding: content/FT_SP500/910.png (deflated 14%)
#   adding: content/FT_SP500/1074.png (deflated 1%)
#   adding: content/FT_SP500/628.png (deflated 5%)
#   adding: content/FT_SP500/293.png (deflated 1%)
#   adding: content/FT_SP500/961.png (deflated 7%)
#   adding: content/FT_SP500/812.png (deflated 3%)
#   adding: content/FT_SP500/1111.png (deflated 1%)
#   adding: content/FT_SP500/495.png (deflated 1%)
#   adding: content/FT_SP500/448.png (deflated 4%)
#   adding: content/FT_SP500/1084.png (deflated 6%)
#   adding: content/FT_SP500/1018.png (deflated 8%)
#   adding: content/FT_SP500/413.png (deflated 23%)
#   adding: content/FT_SP500/461.png (deflated 2%)
#   adding: content/FT_SP500/559.png (deflated 3%)
#   adding: content/FT_SP500/736.png (deflated 3%)
#   adding: content/FT_SP500/321.png (deflated 9%)
#   adding: content/FT_SP500/775.png (deflated 6%)
#   adding: content/FT_SP500/579.png (deflated 4%)
#   adding: content/FT_SP500/955.png (deflated 3%)
#   adding: content/FT_SP500/260.png (deflated 1%)
#   adding: content/FT_SP500/476.png (deflated 2%)
#   adding: content/FT_SP500/996.png (deflated 2%)
#   adding: content/FT_SP500/785.png (deflated 1%)
#   adding: content/FT_SP500/747.png (deflated 3%)
#   adding: content/FT_SP500/152.png (deflated 3%)
#   adding: content/FT_SP500/658.png (deflated 3%)
#   adding: content/FT_SP500/837.png (deflated 2%)
#   adding: content/FT_SP500/1001.png (deflated 1%)
#   adding: content/FT_SP500/614.png (deflated 2%)
#   adding: content/FT_SP500/566.png (deflated 3%)
#   adding: content/FT_SP500/811.png (deflated 2%)
#   adding: content/FT_SP500/288.png (deflated 4%)
#   adding: content/FT_SP500/105.png (deflated 16%)
#   adding: content/FT_SP500/1106.png (deflated 2%)
#   adding: content/FT_SP500/602.png (deflated 4%)
#   adding: content/FT_SP500/810.png (deflated 4%)
#   adding: content/FT_SP500/890.png (deflated 3%)
#   adding: content/FT_SP500/256.png (deflated 1%)
#   adding: content/FT_SP500/561.png (deflated 3%)
#   adding: content/FT_SP500/104.png (deflated 8%)
#   adding: content/FT_SP500/886.png (deflated 1%)
#   adding: content/FT_SP500/227.png (deflated 5%)
#   adding: content/FT_SP500/640.png (deflated 3%)
#   adding: content/FT_SP500/962.png (deflated 2%)
#   adding: content/FT_SP500/1063.png (deflated 2%)
#   adding: content/FT_SP500/912.png (deflated 1%)
#   adding: content/FT_SP500/558.png (deflated 37%)
#   adding: content/FT_SP500/466.png (deflated 2%)
#   adding: content/FT_SP500/643.png (deflated 1%)
#   adding: content/FT_SP500/32.png (deflated 23%)
#   adding: content/FT_SP500/405.png (deflated 1%)
#   adding: content/FT_SP500/435.png (deflated 0%)
#   adding: content/FT_SP500/525.png (deflated 2%)
#   adding: content/FT_SP500/16.png (deflated 3%)
#   adding: content/FT_SP500/657.png (deflated 2%)
#   adding: content/FT_SP500/248.png (deflated 25%)
#   adding: content/FT_SP500/445.png (deflated 5%)
#   adding: content/FT_SP500/230.png (deflated 4%)
#   adding: content/FT_SP500/922.png (deflated 8%)
#   adding: content/FT_SP500/802.png (deflated 4%)
#   adding: content/FT_SP500/139.png (deflated 5%)
#   adding: content/FT_SP500/223.png (deflated 2%)
#   adding: content/FT_SP500/889.png (deflated 2%)
#   adding: content/FT_SP500/1019.png (deflated 3%)
#   adding: content/FT_SP500/296.png (deflated 1%)
#   adding: content/FT_SP500/697.png (deflated 1%)
#   adding: content/FT_SP500/346.png (deflated 4%)
#   adding: content/FT_SP500/12.png (deflated 1%)
#   adding: content/FT_SP500/481.png (deflated 2%)
#   adding: content/FT_SP500/583.png (deflated 36%)
#   adding: content/FT_SP500/711.png (deflated 1%)
#   adding: content/FT_SP500/364.png (deflated 12%)
#   adding: content/FT_SP500/928.png (deflated 4%)
#   adding: content/FT_SP500/964.png (deflated 2%)
#   adding: content/FT_SP500/766.png (deflated 10%)
#   adding: content/FT_SP500/341.png (deflated 16%)
#   adding: content/FT_SP500/291.png (deflated 2%)
#   adding: content/FT_SP500/851.png (deflated 2%)
#   adding: content/FT_SP500/38.png (deflated 3%)
#   adding: content/FT_SP500/384.png (deflated 10%)
#   adding: content/FT_SP500/1033.png (deflated 1%)
#   adding: content/FT_SP500/1113.png (deflated 2%)
#   adding: content/FT_SP500/554.png (deflated 2%)
#   adding: content/FT_SP500/28.png (deflated 30%)
#   adding: content/FT_SP500/239.png (deflated 7%)
#   adding: content/FT_SP500/79.png (deflated 0%)
#   adding: content/FT_SP500/710.png (deflated 4%)
#   adding: content/FT_SP500/675.png (deflated 2%)
#   adding: content/FT_SP500/112.png (deflated 1%)
#   adding: content/FT_SP500/935.png (deflated 1%)
#   adding: content/FT_SP500/698.png (deflated 3%)
#   adding: content/FT_SP500/43.png (deflated 6%)
#   adding: content/FT_SP500/159.png (deflated 2%)
#   adding: content/FT_SP500/267.png (deflated 1%)
#   adding: content/FT_SP500/171.png (deflated 3%)
#   adding: content/FT_SP500/467.png (deflated 2%)
#   adding: content/FT_SP500/533.png (deflated 6%)
#   adding: content/FT_SP500/261.png (deflated 4%)
#   adding: content/FT_SP500/498.png (deflated 3%)
#   adding: content/FT_SP500/691.png (deflated 18%)
#   adding: content/FT_SP500/383.png (deflated 13%)
#   adding: content/FT_SP500/603.png (deflated 2%)
#   adding: content/FT_SP500/1012.png (deflated 1%)
#   adding: content/FT_SP500/831.png (deflated 5%)
#   adding: content/FT_SP500/228.png (deflated 8%)
#   adding: content/FT_SP500/509.png (deflated 1%)
#   adding: content/FT_SP500/85.png (deflated 2%)
#   adding: content/FT_SP500/387.png (deflated 4%)
#   adding: content/FT_SP500/882.png (deflated 11%)
#   adding: content/FT_SP500/1027.png (deflated 1%)
#   adding: content/FT_SP500/728.png (deflated 10%)
#   adding: content/FT_SP500/934.png (deflated 4%)
#   adding: content/FT_SP500/599.png (deflated 4%)
#   adding: content/FT_SP500/351.png (deflated 4%)
#   adding: content/FT_SP500/446.png (deflated 0%)
#   adding: content/FT_SP500/137.png (deflated 3%)
#   adding: content/FT_SP500/374.png (deflated 53%)
#   adding: content/FT_SP500/95.png (deflated 4%)
#   adding: content/FT_SP500/126.png (deflated 3%)
#   adding: content/FT_SP500/202.png (deflated 5%)
#   adding: content/FT_SP500/107.png (deflated 3%)
#   adding: content/FT_SP500/838.png (deflated 3%)
#   adding: content/FT_SP500/576.png (deflated 2%)
#   adding: content/FT_SP500/316.png (deflated 5%)
#   adding: content/FT_SP500/571.png (deflated 2%)
#   adding: content/FT_SP500/367.png (deflated 12%)
#   adding: content/FT_SP500/970.png (deflated 2%)
#   adding: content/FT_SP500/945.png (deflated 1%)
#   adding: content/FT_SP500/52.png (deflated 4%)
#   adding: content/FT_SP500/83.png (deflated 1%)
#   adding: content/FT_SP500/1101.png (deflated 1%)
#   adding: content/FT_SP500/166.png (deflated 32%)
#   adding: content/FT_SP500/693.png (deflated 4%)
#   adding: content/FT_SP500/320.png (deflated 3%)
#   adding: content/FT_SP500/887.png (deflated 1%)
#   adding: content/FT_SP500/770.png (deflated 12%)
#   adding: content/FT_SP500/390.png (deflated 1%)
#   adding: content/FT_SP500/370.png (deflated 2%)
#   adding: content/FT_SP500/1059.png (deflated 1%)
#   adding: content/FT_SP500/33.png (deflated 3%)
#   adding: content/FT_SP500/474.png (deflated 3%)
#   adding: content/FT_SP500/122.png (deflated 1%)
#   adding: content/FT_SP500/952.png (deflated 2%)
#   adding: content/FT_SP500/630.png (deflated 1%)
#   adding: content/FT_SP500/582.png (deflated 7%)
#   adding: content/FT_SP500/146.png (deflated 2%)
#   adding: content/FT_SP500/800.png (deflated 4%)
#   adding: content/FT_SP500/67.png (deflated 1%)
#   adding: content/FT_SP500/235.png (deflated 2%)
#   adding: content/FT_SP500/77.png (deflated 2%)
#   adding: content/FT_SP500/342.png (deflated 6%)
#   adding: content/FT_SP500/793.png (deflated 4%)
#   adding: content/FT_SP500/26.png (deflated 2%)
#   adding: content/FT_SP500/496.png (deflated 3%)
#   adding: content/FT_SP500/331.png (deflated 2%)
#   adding: content/FT_SP500/740.png (deflated 4%)
#   adding: content/FT_SP500/236.png (deflated 18%)
#   adding: content/FT_SP500/716.png (deflated 0%)
#   adding: content/FT_SP500/4.png (deflated 23%)
#   adding: content/FT_SP500/421.png (deflated 2%)
#   adding: content/FT_SP500/528.png (deflated 5%)
#   adding: content/FT_SP500/477.png (deflated 4%)
#   adding: content/FT_SP500/40.png (deflated 1%)
#   adding: content/FT_SP500/1072.png (deflated 7%)
#   adding: content/FT_SP500/102.png (deflated 3%)
#   adding: content/FT_SP500/24.png (deflated 4%)
#   adding: content/FT_SP500/1058.png (deflated 1%)
#   adding: content/FT_SP500/100.png (deflated 2%)
#   adding: content/FT_SP500/512.png (deflated 2%)
#   adding: content/FT_SP500/622.png (deflated 1%)
#   adding: content/FT_SP500/510.png (deflated 2%)
#   adding: content/FT_SP500/958.png (deflated 3%)
#   adding: content/FT_SP500/358.png (deflated 1%)
#   adding: content/FT_SP500/82.png (deflated 32%)
#   adding: content/FT_SP500/257.png (deflated 5%)
#   adding: content/FT_SP500/1092.png (deflated 13%)
#   adding: content/FT_SP500/440.png (deflated 1%)
#   adding: content/FT_SP500/360.png (deflated 3%)
#   adding: content/FT_SP500/34.png (deflated 3%)
#   adding: content/FT_SP500/1100.png (deflated 1%)
#   adding: content/FT_SP500/120.png (deflated 32%)
#   adding: content/FT_SP500/1002.png (deflated 3%)
#   adding: content/FT_SP500/1020.png (deflated 1%)
#   adding: content/FT_SP500/207.png (deflated 6%)
#   adding: content/FT_SP500/131.png (deflated 1%)
#   adding: content/FT_SP500/429.png (deflated 3%)
#   adding: content/FT_SP500/196.png (deflated 6%)
#   adding: content/FT_SP500/676.png (deflated 3%)
#   adding: content/FT_SP500/438.png (deflated 2%)
#   adding: content/FT_SP500/700.png (deflated 7%)
#   adding: content/FT_SP500/754.png (deflated 5%)
#   adding: content/FT_SP500/350.png (deflated 3%)
#   adding: content/FT_SP500/692.png (deflated 2%)
#   adding: content/FT_SP500/523.png (deflated 1%)
#   adding: content/FT_SP500/50.png (deflated 30%)
#   adding: content/FT_SP500/635.png (deflated 0%)
#   adding: content/FT_SP500/696.png (deflated 13%)
#   adding: content/FT_SP500/18.png (deflated 5%)
#   adding: content/FT_SP500/423.png (deflated 5%)
#   adding: content/FT_SP500/575.png (deflated 4%)
#   adding: content/FT_SP500/281.png (deflated 3%)
#   adding: content/FT_SP500/1036.png (deflated 36%)
#   adding: content/FT_SP500/760.png (deflated 4%)
#   adding: content/FT_SP500/155.png (deflated 1%)
#   adding: content/FT_SP500/883.png (deflated 0%)
#   adding: content/FT_SP500/713.png (deflated 2%)
#   adding: content/FT_SP500/824.png (deflated 2%)
#   adding: content/FT_SP500/352.png (deflated 2%)
#   adding: content/FT_SP500/817.png (deflated 2%)
#   adding: content/FT_SP500/115.png (deflated 3%)
#   adding: content/FT_SP500/64.png (deflated 1%)
#   adding: content/FT_SP500/861.png (deflated 2%)
#   adding: content/FT_SP500/607.png (deflated 3%)
#   adding: content/FT_SP500/20.png (deflated 3%)
#   adding: content/FT_SP500/591.png (deflated 5%)
#   adding: content/FT_SP500/649.png (deflated 4%)
#   adding: content/FT_SP500/940.png (deflated 1%)
#   adding: content/FT_SP500/472.png (deflated 25%)
#   adding: content/FT_SP500/668.png (deflated 1%)
#   adding: content/FT_SP500/832.png (deflated 2%)
#   adding: content/FT_SP500/975.png (deflated 4%)
#   adding: content/FT_SP500/953.png (deflated 1%)
#   adding: content/FT_SP500/787.png (deflated 0%)
#   adding: content/FT_SP500/917.png (deflated 5%)
#   adding: content/FT_SP500/978.png (deflated 36%)
#   adding: content/FT_SP500/238.png (deflated 32%)
#   adding: content/FT_SP500/721.png (deflated 11%)
#   adding: content/FT_SP500/879.png (deflated 3%)
#   adding: content/FT_SP500/769.png (deflated 1%)
#   adding: content/FT_SP500/839.png (deflated 0%)
#   adding: content/FT_SP500/317.png (deflated 3%)
#   adding: content/FT_SP500/23.png (deflated 3%)
#   adding: content/FT_SP500/967.png (deflated 0%)
#   adding: content/FT_SP500/418.png (deflated 2%)
#   adding: content/FT_SP500/530.png (deflated 1%)
#   adding: content/FT_SP500/517.png (deflated 1%)
#   adding: content/FT_SP500/846.png (deflated 6%)
#   adding: content/FT_SP500/345.png (deflated 2%)
#   adding: content/FT_SP500/725.png (deflated 4%)
#   adding: content/FT_SP500/650.png (deflated 2%)
#   adding: content/FT_SP500/836.png (deflated 5%)
#   adding: content/FT_SP500/428.png (deflated 6%)
#   adding: content/FT_SP500/527.png (deflated 3%)
#   adding: content/FT_SP500/133.png (deflated 4%)
#   adding: content/FT_SP500/820.png (deflated 1%)
#   adding: content/FT_SP500/430.png (deflated 2%)
#   adding: content/FT_SP500/1115.png (deflated 3%)
#   adding: content/FT_SP500/41.png (deflated 1%)
#   adding: content/FT_SP500/302.png (deflated 23%)
#   adding: content/FT_SP500/815.png (deflated 1%)
#   adding: content/FT_SP500/1104.png (deflated 1%)
#   adding: content/FT_SP500/904.png (deflated 2%)
#   adding: content/FT_SP500/556.png (deflated 1%)
#   adding: content/FT_SP500/180.png (deflated 4%)
#   adding: content/FT_SP500/726.png (deflated 8%)
#   adding: content/FT_SP500/190.png (deflated 32%)
#   adding: content/FT_SP500/762.png (deflated 9%)
#   adding: content/FT_SP500/386.png (deflated 2%)
#   adding: content/FT_SP500/482.png (deflated 2%)
#   adding: content/FT_SP500/550.png (deflated 1%)
#   adding: content/FT_SP500/677.png (deflated 10%)
#   adding: content/FT_SP500/943.png (deflated 1%)
#   adding: content/FT_SP500/60.png (deflated 1%)
#   adding: content/FT_SP500/905.png (deflated 3%)
#   adding: content/FT_SP500/783.png (deflated 10%)
#   adding: content/FT_SP500/966.png (deflated 1%)
#   adding: content/FT_SP500/581.png (deflated 3%)
#   adding: content/FT_SP500/932.png (deflated 7%)
#   adding: content/FT_SP500/794.png (deflated 2%)
#   adding: content/FT_SP500/68.png (deflated 1%)
#   adding: content/FT_SP500/3.png (deflated 1%)
#   adding: content/FT_SP500/733.png (deflated 1%)
#   adding: content/FT_SP500/895.png (deflated 4%)
#   adding: content/FT_SP500/240.png (deflated 2%)
#   adding: content/FT_SP500/97.png (deflated 1%)
#   adding: content/FT_SP500/924.png (deflated 5%)
#   adding: content/FT_SP500/896.png (deflated 3%)
#   adding: content/FT_SP500/908.png (deflated 5%)
#   adding: content/FT_SP500/666.png (deflated 5%)
#   adding: content/FT_SP500/729.png (deflated 3%)
#   adding: content/FT_SP500/546.png (deflated 1%)
#   adding: content/FT_SP500/1016.png (deflated 5%)
#   adding: content/FT_SP500/541.png (deflated 1%)
#   adding: content/FT_SP500/947.png (deflated 2%)
#   adding: content/FT_SP500/323.png (deflated 10%)
#   adding: content/FT_SP500/753.png (deflated 1%)
#   adding: content/FT_SP500/551.png (deflated 2%)
#   adding: content/FT_SP500/1000.png (deflated 16%)
#   adding: content/FT_SP500/324.png (deflated 2%)
#   adding: content/FT_SP500/452.png (deflated 22%)
#   adding: content/FT_SP500/194.png (deflated 2%)
#   adding: content/FT_SP500/807.png (deflated 5%)
#   adding: content/FT_SP500/348.png (deflated 14%)
#   adding: content/FT_SP500/570.png (deflated 0%)
#   adding: content/FT_SP500/772.png (deflated 3%)
#   adding: content/FT_SP500/298.png (deflated 1%)
#   adding: content/FT_SP500/407.png (deflated 2%)
#   adding: content/FT_SP500/621.png (deflated 2%)
#   adding: content/FT_SP500/400.png (deflated 2%)
#   adding: content/FT_SP500/685.png (deflated 1%)
#   adding: content/FT_SP500/827.png (deflated 5%)
#   adding: content/FT_SP500/285.png (deflated 7%)
#   adding: content/FT_SP500/222.png (deflated 1%)
#   adding: content/FT_SP500/441.png (deflated 5%)
#   adding: content/FT_SP500/1048.png (deflated 1%)
#   adding: content/FT_SP500/765.png (deflated 2%)
#   adding: content/FT_SP500/492.png (deflated 3%)
#   adding: content/FT_SP500/425.png (deflated 3%)
#   adding: content/FT_SP500/596.png (deflated 3%)
#   adding: content/FT_SP500/1089.png (deflated 3%)
#   adding: content/FT_SP500/10.png (deflated 3%)
#   adding: content/FT_SP500/574.png (deflated 8%)
#   adding: content/FT_SP500/723.png (deflated 1%)
#   adding: content/FT_SP500/48.png (deflated 3%)
#   adding: content/FT_SP500/451.png (deflated 32%)
#   adding: content/FT_SP500/206.png (deflated 1%)
#   adding: content/FT_SP500/1041.png (deflated 1%)
#   adding: content/FT_SP500/62.png (deflated 24%)
#   adding: content/FT_SP500/867.png (deflated 1%)
#   adding: content/FT_SP500/719.png (deflated 3%)
#   adding: content/FT_SP500/385.png (deflated 32%)
#   adding: content/FT_SP500/619.png (deflated 6%)
#   adding: content/FT_SP500/375.png (deflated 2%)
#   adding: content/FT_SP500/66.png (deflated 1%)
#   adding: content/FT_SP500/431.png (deflated 0%)
#   adding: content/FT_SP500/1068.png (deflated 1%)
#   adding: content/FT_SP500/179.png (deflated 31%)
#   adding: content/FT_SP500/701.png (deflated 2%)
#   adding: content/FT_SP500/355.png (deflated 36%)
#   adding: content/FT_SP500/942.png (deflated 4%)
#   adding: content/FT_SP500/1004.png (deflated 3%)
#   adding: content/FT_SP500/948.png (deflated 13%)
#   adding: content/FT_SP500/663.png (deflated 2%)
#   adding: content/FT_SP500/923.png (deflated 8%)
#   adding: content/FT_SP500/1039.png (deflated 1%)
#   adding: content/FT_SP500/271.png (deflated 8%)
#   adding: content/FT_SP500/776.png (deflated 5%)
#   adding: content/FT_SP500/944.png (deflated 1%)
#   adding: content/FT_SP500/132.png (deflated 3%)
#   adding: content/FT_SP500/389.png (deflated 3%)
#   adding: content/FT_SP500/536.png (deflated 0%)
#   adding: content/FT_SP500/592.png (deflated 2%)
#   adding: content/FT_SP500/744.png (deflated 1%)
#   adding: content/FT_SP500/176.png (deflated 16%)
#   adding: content/FT_SP500/850.png (deflated 3%)
#   adding: content/FT_SP500/1075.png (deflated 1%)

# %%
# !pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepface
#   Downloading deepface-0.0.79-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.9/dist-packages (from deepface) (4.7.0.72)
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from deepface) (2.12.0)
# Collecting retina-face>=0.0.1
#   Downloading retina_face-0.0.13-py3-none-any.whl (16 kB)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from deepface) (2.12.0)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.9/dist-packages (from deepface) (1.5.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from deepface) (1.22.4)
# Collecting mtcnn>=0.1.0
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 48.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.9/dist-packages (from deepface) (4.65.0)
# Requirement already satisfied: Flask>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from deepface) (2.2.3)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.9/dist-packages (from deepface) (8.4.0)
# Collecting fire>=0.4.0
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.9/dist-packages (from deepface) (4.6.6)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from fire>=0.4.0->deepface) (2.2.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.1.2->deepface) (6.4.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.1.2->deepface) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown>=3.10.1->deepface) (3.11.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown>=3.10.1->deepface) (4.11.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from gdown>=3.10.1->deepface) (2.27.1)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.9/dist-packages (from gunicorn>=20.1.0->deepface) (67.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.23.4->deepface) (2022.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (23.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (1.53.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (2.12.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (16.0.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (2.12.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (23.3.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (3.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=1.9.0->deepface) (4.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.40.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.15.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=1.9.0->deepface) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=1.9.0->deepface) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (2.17.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=0072c243d7784a566f34c7616006c9412c73d1a52752fcbb55ba11f80acccbb5
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built fire
# Installing collected packages: gunicorn, fire, mtcnn, retina-face, deepface
# Successfully installed deepface-0.0.79 fire-0.5.0 gunicorn-20.1.0 mtcnn-0.1.1 retina-face-0.0.13

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
# !pip install fer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fer
#   Downloading fer-22.5.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 35.9 MB/s eta 0:00:00
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.5.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 67.5 MB/s eta 0:00:00
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from fer) (2.12.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from fer) (3.7.1)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.9/dist-packages (from fer) (4.7.0.72)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from fer) (4.65.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from fer) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from fer) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from facenet-pytorch->fer) (1.22.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from facenet-pytorch->fer) (0.15.1+cu118)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from facenet-pytorch->fer) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fer) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fer) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fer) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fer) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fer) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fer) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fer) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fer) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->fer) (2022.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->fer) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->fer) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->fer) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->fer) (2.0.12)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->fer) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->fer) (1.16.0)
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->facenet-pytorch->fer) (2.0.0+cu118)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->torchvision->facenet-pytorch->fer) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->torchvision->facenet-pytorch->fer) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->torchvision->facenet-pytorch->fer) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->torchvision->facenet-pytorch->fer) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->torchvision->facenet-pytorch->fer) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->torchvision->facenet-pytorch->fer) (1.11.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision->facenet-pytorch->fer) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision->facenet-pytorch->fer) (16.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch==2.0.0->torchvision->facenet-pytorch->fer) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch==2.0.0->torchvision->facenet-pytorch->fer) (1.3.0)
# Installing collected packages: facenet-pytorch, fer
# Successfully installed facenet-pytorch-2.5.3 fer-22.5.0

# %%
from fer import FER
import cv2

# %%
emotion_detector = FER(mtcnn=True)

# %%
from collections import Counter
def get_emotion_from_image(image_path):
  try:
    test_img = cv2.imread(image_path)
    analysis = emotion_detector.detect_emotions(test_img)
    emotion_store=[]
    emotion_score_all=0
    print(analysis)
    for index in range(len(analysis)):
      emotion_this=analysis[index]['emotions']
      emotion_name=max(emotion_this , key=emotion_this.get)
      if emotion_name in ["angry","digust","fear","sad"]:
        emotion_classify="negative"
        emotion_score=-1
        emotion_score_all+=emotion_score
      elif emotion_name in ["happy"]:
        emotion_classify="positive"
        emotion_score=2
        emotion_score_all+=emotion_score
      elif emotion_name in ["neutral","surprise"]:
        emotion_classify="neutral"
        emotion_score=1
        emotion_score_all+=emotion_score
      emotion_store.append(emotion_classify)
    emotion_statistics=Counter(emotion_store)
    emotion_most=emotion_statistics.most_common(1)[0][0]
    
    return emotion_most, emotion_store, emotion_score_all
  except:
    pass
    return 'No face detected', 'No face detected', 0

# %%
emotionList = []
emotionOther = []
emotionScore = []
for i in range(len(df)):
  try:
    emotion_result, emotion_other, emotion_score = get_emotion_from_image(f"/content/FT_SP500/{i}.png")
  except Error:
    emotion_result = 'None'
  emotionList.append(emotion_result)
  emotionOther.append(emotion_other)
  emotionScore.append(emotion_score)
# Out:
# []
# []
# []
# []
# []
# [{'box': [224, 198, 113, 156], 'emotions': {'angry': 0.05, 'disgust': 0.0, 'fear': 0.13, 'happy': 0.06, 'sad': 0.13, 'surprise': 0.1, 'neutral': 0.53}}]
# []
# []
# [{'box': [927, 780, 36, 50], 'emotions': {'angry': 0.48, 'disgust': 0.01, 'fear': 0.04, 'happy': 0.11, 'sad': 0.33, 'surprise': 0.02, 'neutral': 0.02}}, {'box': [1886, 517, 31, 39], 'emotions': {'angry': 0.34, 'disgust': 0.05, 'fear': 0.22, 'happy': 0.01, 'sad': 0.15, 'surprise': 0.2, 'neutral': 0.03}}]
# []
# []
# []
# []
# [{'box': [352, 174, 386, 485], 'emotions': {'angry': 0.5, 'disgust': 0.1, 'fear': 0.05, 'happy': 0.0, 'sad': 0.2, 'surprise': 0.0, 'neutral': 0.13}}]
# [{'box': [1030, 778, 15, 20], 'emotions': {'angry': 0.23, 'disgust': 0.0, 'fear': 0.13, 'happy': 0.04, 'sad': 0.5, 'surprise': 0.01, 'neutral': 0.09}}]
# []
# [{'box': [1326, 104, 19, 27], 'emotions': {'angry': 0.16, 'disgust': 0.0, 'fear': 0.2, 'happy': 0.04, 'sad': 0.54, 'surprise': 0.05, 'neutral': 0.02}}]
# []
# []
# []
# [{'box': [546, 935, 22, 25], 'emotions': {'angry': 0.19, 'disgust': 0.0, 'fear': 0.06, 'happy': 0.01, 'sad': 0.61, 'surprise': 0.02, 'neutral': 0.1}}]
# []
# []
# []
# []
# []
# [{'box': [224, 198, 113, 156], 'emotions': {'angry': 0.05, 'disgust': 0.0, 'fear': 0.13, 'happy': 0.06, 'sad': 0.13, 'surprise': 0.1, 'neutral': 0.53}}]
# []
# []
# [{'box': [927, 780, 36, 50], 'emotions': {'angry': 0.48, 'disgust': 0.01, 'fear': 0.04, 'happy': 0.11, 'sad': 0.33, 'surprise': 0.02, 'neutral': 0.02}}, {'box': [1886, 517, 31, 39], 'emotions': {'angry': 0.34, 'disgust': 0.05, 'fear': 0.22, 'happy': 0.01, 'sad': 0.15, 'surprise': 0.2, 'neutral': 0.03}}]
# []
# []
# []
# []
# [{'box': [352, 174, 386, 485], 'emotions': {'angry': 0.5, 'disgust': 0.1, 'fear': 0.05, 'happy': 0.0, 'sad': 0.2, 'surprise': 0.0, 'neutral': 0.13}}]
# [{'box': [1030, 778, 15, 20], 'emotions': {'angry': 0.23, 'disgust': 0.0, 'fear': 0.13, 'happy': 0.04, 'sad': 0.5, 'surprise': 0.01, 'neutral': 0.09}}]
59, 'surprise': 0.0, 'neutral': 0.17}}, {'box': [1086, 325, 49, 65], 'emotions': {'angry': 0.52, 'disgust': 0.03, 'fear': 0.01, 'happy': 0.07, 'sad': 0.06, 'surprise': 0.0, 'neutral': 0.32}}, {'box': [773, 659, 45, 56], 'emotions': {'angry': 0.07, 'disgust': 0.0, 'fear': 0.01, 'happy': 0.81, 'sad': 0.05, 'surprise': 0.01, 'neutral': 0.04}}, {'box': [640, 429, 41, 54], 'emotions': {'angry': 0.53, 'disgust': 0.03, 'fear': 0.02, 'happy': 0.0, 'sad': 0.37, 'surprise': 0.0, 'neutral': 0.04}}]
# []
# []
# [{'box': [244, 816, 33, 39], 'emotions': {'angry': 0.58, 'disgust': 0.01, 'fear': 0.11, 'happy': 0.09, 'sad': 0.1, 'surprise': 0.03, 'neutral': 0.08}}]
# []
# []
# []
# []
# [{'box': [2082, 802, 57, 69], 'emotions': {'angry': 0.03, 'disgust': 0.0, 'fear': 0.03, 'happy': 0.05, 'sad': 0.2, 'surprise': 0.01, 'neutral': 0.69}}]
# []
# []
# [{'box': [785, 124, 265, 325], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 1.0, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.0}}]

# %%
df['emotion_face'] = emotionList

# %%
df['emotion_all'] = emotionOther

# %%
df['emotion_score'] = emotionScore

# %%
#df['emotion_score'] = df['emotion_score'].replace('None', 0 , regex = True)

# %%
df.to_csv('FT_S&P500_emotion.csv')

# %% [markdown]
# # Score

# %%
df['text&emotion_score'] = df['emotion_score'] + df['text_score']

# %%
df['total_score'] = df['emotion_score'] + df['content_score']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               1120 non-null   object
#  1   image               1120 non-null   object
#  2   description         1120 non-null   object
#  3   time                999 non-null    object
#  4   date                1120 non-null   object
#  5   title&desc          1120 non-null   object
#  6   text_score          1120 non-null   int64
#  7   text_label          1120 non-null   object
#  8   title_score         1120 non-null   int64
#  9   title_label         1120 non-null   object
#  10  description_score   1120 non-null   int64
#  11  description_label   1120 non-null   object
#  12  image_desc          1120 non-null   object
#  13  content             1120 non-null   object
#  14  content_score       1120 non-null   int64
#  15  content_label       1120 non-null   object
#  16  emotion_face        1120 non-null   object
#  17  emotion_all         1120 non-null   object
#  18  emotion_score       1120 non-null   int64
#  19  text&emotion_score  1120 non-null   int64
#  20  total_score         1120 non-null   int64
# dtypes: int64(7), object(14)
# memory usage: 183.9+ KB

# %%
df.describe()
# Out:
#         text_score  title_score  description_score  content_score  \
# count  1120.000000  1120.000000        1120.000000    1120.000000
# mean      0.931250     0.985714           0.957143       0.952679
# std       0.870377     0.747813           0.840200       0.867696
# min       0.000000     0.000000           0.000000       0.000000
# 25%       0.000000     0.000000           0.000000       0.000000
# 50%       1.000000     1.000000           1.000000       1.000000
# 75%       2.000000     2.000000           2.000000       2.000000
# max       2.000000     2.000000           2.000000       2.000000
#
#        emotion_score  text&emotion_score  total_score
# count    1120.000000         1120.000000  1120.000000
# mean       -0.040179            0.891071     0.912500
# std         0.942110            1.280468     1.286982
# min        -7.000000           -6.000000    -6.000000
# 25%         0.000000            0.000000     0.000000
# 50%         0.000000            1.000000     1.000000
# 75%         0.000000            2.000000     2.000000
# max         7.000000            9.000000     9.000000

# %% [markdown]
# # Financial Data and Merge Result

# %%
import yfinance as yf

# %%
SP500 = yf.download('^GSPC',period= '5y', interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SP500['date'] = SP500.index

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2018-04-20 to 2023-04-19
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1258 non-null   float64
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Adj Close  1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   date       1258 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 78.6 KB

# %%
SP500['gap'] = SP500.Close.diff()

# %%
SP500.loc[SP500['gap'] >= 0,'gap'] = 1
SP500.loc[SP500['gap'] < 0,'gap'] = 0

# %%
SP500
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-04-20  2692.560059  2693.939941  2660.610107  2670.139893  2670.139893
# 2018-04-23  2675.399902  2682.860107  2657.989990  2670.290039  2670.290039
# 2018-04-24  2680.800049  2683.550049  2617.320068  2634.560059  2634.560059
# 2018-04-25  2634.919922  2645.300049  2612.669922  2639.399902  2639.399902
# 2018-04-26  2651.649902  2676.479980  2647.159912  2666.939941  2666.939941
# ...                 ...          ...          ...          ...          ...
# 2023-04-13  4100.040039  4150.259766  4099.399902  4146.220215  4146.220215
# 2023-04-14  4140.109863  4163.189941  4113.200195  4137.640137  4137.640137
# 2023-04-17  4137.169922  4151.720215  4123.180176  4151.319824  4151.319824
# 2023-04-18  4164.259766  4169.479980  4140.359863  4154.870117  4154.870117
# 2023-04-19  4139.330078  4162.569824  4134.490234  4154.520020  4154.520020
#
#                 Volume       date  gap
# Date
# 2018-04-20  3428260000 2018-04-20  NaN
# 2018-04-23  3030390000 2018-04-23  1.0
# 2018-04-24  3716020000 2018-04-24  0.0
# 2018-04-25  3563680000 2018-04-25  1.0
# 2018-04-26  3690920000 2018-04-26  1.0
# ...                ...        ...  ...
# 2023-04-13  3596590000 2023-04-13  1.0
# 2023-04-14  3575690000 2023-04-14  0.0
# 2023-04-17  3611180000 2023-04-17  1.0
# 2023-04-18  3536640000 2023-04-18  1.0
# 2023-04-19  3572560000 2023-04-19  0.0
#
# [1258 rows x 8 columns]

# %%
SP500.to_csv('SP500.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               1120 non-null   object
#  1   image               1120 non-null   object
#  2   description         1120 non-null   object
#  3   time                999 non-null    object
#  4   date                1120 non-null   object
#  5   title&desc          1120 non-null   object
#  6   text_score          1120 non-null   int64
#  7   text_label          1120 non-null   object
#  8   title_score         1120 non-null   int64
#  9   title_label         1120 non-null   object
#  10  description_score   1120 non-null   int64
#  11  description_label   1120 non-null   object
#  12  image_desc          1120 non-null   object
#  13  content             1120 non-null   object
#  14  content_score       1120 non-null   int64
#  15  content_label       1120 non-null   object
#  16  emotion_face        1120 non-null   object
#  17  emotion_all         1120 non-null   object
#  18  emotion_score       1120 non-null   int64
#  19  text&emotion_score  1120 non-null   int64
#  20  total_score         1120 non-null   int64
# dtypes: int64(7), object(14)
# memory usage: 183.9+ KB

# %%
df.to_csv('FT_S&P500_score.csv')

# %%
df['date'] = df['date'].replace('None', 0, regex = True)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df_merge = pd.merge(df, SP500, on='date')

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 924 entries, 0 to 923
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               924 non-null    object
#  1   image               924 non-null    object
#  2   description         924 non-null    object
#  3   time                924 non-null    object
#  4   date                924 non-null    datetime64[ns]
#  5   title&desc          924 non-null    object
#  6   text_score          924 non-null    int64
#  7   text_label          924 non-null    object
#  8   title_score         924 non-null    int64
#  9   title_label         924 non-null    object
#  10  description_score   924 non-null    int64
#  11  description_label   924 non-null    object
#  12  image_desc          924 non-null    object
#  13  content             924 non-null    object
#  14  content_score       924 non-null    int64
#  15  content_label       924 non-null    object
#  16  emotion_face        924 non-null    object
#  17  emotion_all         924 non-null    object
#  18  emotion_score       924 non-null    int64
#  19  text&emotion_score  924 non-null    int64
#  20  total_score         924 non-null    int64
#  21  Open                924 non-null    float64
#  22  High                924 non-null    float64
#  23  Low                 924 non-null    float64
#  24  Close               924 non-null    float64
#  25  Adj Close           924 non-null    float64
#  26  Volume              924 non-null    int64
#  27  gap                 924 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(8), object(13)
# memory usage: 209.3+ KB

# %%
df_merge.corr()
# Out:
#                     text_score  title_score  description_score  content_score  \
# text_score            1.000000     0.500143           0.849496       0.936252
# title_score           0.500143     1.000000           0.340943       0.528428
# description_score     0.849496     0.340943           1.000000       0.816092
# content_score         0.936252     0.528428           0.816092       1.000000
# emotion_score         0.002056     0.041655          -0.003958       0.013729
# text&emotion_score    0.684697     0.372057           0.577489       0.649652
# total_score           0.636440     0.388597           0.550585       0.688142
# Open                  0.017613     0.029114           0.028370       0.018844
# High                  0.040970     0.058009           0.053606       0.045957
# Low                   0.033211     0.051303           0.051965       0.038332
# Close                 0.054193     0.066966           0.077217       0.061189
# Adj Close             0.054193     0.066966           0.077217       0.061189
# Volume               -0.017986    -0.009773          -0.033862      -0.033278
# gap                   0.190129     0.170030           0.224520       0.194649
#
#                     emotion_score  text&emotion_score  total_score      Open  \
# text_score               0.002056            0.684697     0.636440  0.017613
# title_score              0.041655            0.372057     0.388597  0.029114
# description_score       -0.003958            0.577489     0.550585  0.028370
# content_score            0.013729            0.649652     0.688142  0.018844
# emotion_score            1.000000            0.730234     0.734955 -0.006893
# text&emotion_score       0.730234            1.000000     0.970471  0.007009
# total_score              0.734955            0.970471     1.000000  0.007778
# Open                    -0.006893            0.007009     0.007778  1.000000
# High                    -0.005388            0.024063     0.027257  0.977549
# Low                     -0.011871            0.014038     0.017382  0.976487
# Close                   -0.007611            0.031478     0.035975  0.937462
# Adj Close               -0.007611            0.031478     0.035975  0.937462
# Volume                   0.049609            0.023869     0.013430 -0.163609
# gap                      0.036109            0.156213     0.158209 -0.012367
#
#                         High       Low     Close  Adj Close    Volume  \
# text_score          0.040970  0.033211  0.054193   0.054193 -0.017986
# title_score         0.058009  0.051303  0.066966   0.066966 -0.009773
# description_score   0.053606  0.051965  0.077217   0.077217 -0.033862
# content_score       0.045957  0.038332  0.061189   0.061189 -0.033278
# emotion_score      -0.005388 -0.011871 -0.007611  -0.007611  0.049609
# text&emotion_score  0.024063  0.014038  0.031478   0.031478  0.023869
# total_score         0.027257  0.017382  0.035975   0.035975  0.013430
# Open                0.977549  0.976487  0.937462   0.937462 -0.163609
# High                1.000000  0.976890  0.970980   0.970980 -0.165188
# Low                 0.976890  1.000000  0.976852   0.976852 -0.220343
# Close               0.970980  0.976852  1.000000   1.000000 -0.212474
# Adj Close           0.970980  0.976852  1.000000   1.000000 -0.212474
# Volume             -0.165188 -0.220343 -0.212474  -0.212474  1.000000
# gap                 0.104699  0.105135  0.224374   0.224374 -0.151384
#
#                          gap
# text_score          0.190129
# title_score         0.170030
# description_score   0.224520
# content_score       0.194649
# emotion_score       0.036109
# text&emotion_score  0.156213
# total_score         0.158209
# Open               -0.012367
# High                0.104699
# Low                 0.105135
# Close               0.224374
# Adj Close           0.224374
# Volume             -0.151384
# gap                 1.000000

# %%
df_merge.to_csv('FT_S&P500_analysis.csv')
#df_merge = pd.read_csv('Tesla_analysis.csv')

# %%
def merge_all(df, key_word = 'date', news_amounts = 'news_amount', text_score_name="text_score",image_score_name="emotion_score",total_score_name="total_score", text_emotion_score_name='text&emotion_score', content_score_name='content_score', description_score_name='description_score',title_score_name='title_score'):
  time_unique=np.unique(df[key_word])
  df_amount = pd.DataFrame(columns=[key_word,news_amounts,text_score_name,image_score_name,total_score_name,text_emotion_score_name, title_score_name, description_score_name, content_score_name, "gap", 'Volume'])
  for time_get in time_unique:
    df_get_this_time_data=df[df[key_word]==time_get]
    news_amount = len(df_get_this_time_data[text_score_name])
    text_score=np.mean(df_get_this_time_data[text_score_name].values)#Or, text_score=np.mean(df_get_this_time_data["text_score"].values)
    image_score=np.mean(df_get_this_time_data[image_score_name].values) # Or,  image_score=np.mean(df_get_this_time_data["image_score"].values)
    total_score=np.mean(df_get_this_time_data[total_score_name].values)
    text_emotion_score=np.mean(df_get_this_time_data[text_emotion_score_name].values)
    content_score=np.mean(df_get_this_time_data[content_score_name].values)
    title_score=np.mean(df_get_this_time_data[title_score_name].values)
    description_score=np.mean(df_get_this_time_data[description_score_name].values)
    #print(total_score)
    # image_score=np.mean(df_get_this_time_data["image_score"])
    df_amount = df_amount._append({key_word:time_get, news_amounts: news_amount, text_score_name: text_score, image_score_name: image_score,total_score_name: total_score,text_emotion_score_name: text_emotion_score, content_score_name: content_score, description_score_name:description_score, title_score_name: title_score, "gap":df_get_this_time_data["gap"].values[0], "Volume":df_get_this_time_data["Volume"].values[0]}, ignore_index=True)

# panda_frame_file.set_index("time", drop=False)
  return df_amount

# %%
df_final = merge_all(df_merge, 'date')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                90 non-null     datetime64[ns]
#  1   news_amount         90 non-null     object
#  2   text_score          90 non-null     float64
#  3   emotion_score       90 non-null     float64
#  4   total_score         90 non-null     float64
#  5   text&emotion_score  90 non-null     float64
#  6   title_score         90 non-null     float64
#  7   description_score   90 non-null     float64
#  8   content_score       90 non-null     float64
#  9   gap                 90 non-null     float64
#  10  Volume              90 non-null     object
# dtypes: datetime64[ns](1), float64(8), object(2)
# memory usage: 7.9+ KB

# %%
df_final['news_amount'] = df_final['news_amount'].astype(str).astype(int)
#df_final['total_all_score'] = df_final['total_all_score'].astype(str).astype(float)
df_final['Volume'] = df_final['Volume'].astype(str).astype(float)

# %%
df_final.corr()
# Out:
#                     news_amount  text_score  emotion_score  total_score  \
# news_amount            1.000000   -0.025587      -0.082498    -0.061110
# text_score            -0.025587    1.000000       0.159029     0.752668
# emotion_score         -0.082498    0.159029       1.000000     0.737322
# total_score           -0.061110    0.752668       0.737322     1.000000
# text&emotion_score    -0.070566    0.767462       0.754985     0.978705
# title_score           -0.117840    0.638718       0.130711     0.517188
# description_score     -0.001876    0.898596       0.128166     0.683543
# content_score         -0.012296    0.953695       0.144022     0.774689
# gap                    0.016572    0.496281       0.111152     0.394558
# Volume                 0.259841   -0.000809       0.024619    -0.002126
#
#                     text&emotion_score  title_score  description_score  \
# news_amount                  -0.070566    -0.117840          -0.001876
# text_score                    0.767462     0.638718           0.898596
# emotion_score                 0.754985     0.130711           0.128166
# total_score                   0.978705     0.517188           0.683543
# text&emotion_score            1.000000     0.509112           0.680069
# title_score                   0.509112     1.000000           0.505069
# description_score             0.680069     0.505069           1.000000
# content_score                 0.726961     0.635256           0.881325
# gap                           0.401805     0.500566           0.522386
# Volume                        0.015449     0.012460          -0.032238
#
#                     content_score       gap    Volume
# news_amount             -0.012296  0.016572  0.259841
# text_score               0.953695  0.496281 -0.000809
# emotion_score            0.144022  0.111152  0.024619
# total_score              0.774689  0.394558 -0.002126
# text&emotion_score       0.726961  0.401805  0.015449
# title_score              0.635256  0.500566  0.012460
# description_score        0.881325  0.522386 -0.032238
# content_score            1.000000  0.473929 -0.026158
# gap                      0.473929  1.000000 -0.095120
# Volume                  -0.026158 -0.095120  1.000000

# %%
df_final.to_csv('FT_S&P500_final.csv')

# %%
df_correlation = df_final.corr()

# %%
df_correlation.to_csv('FT_S&P500_correlation.csv')

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns

# %% [markdown]
# ## Heatmap

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.heatmap(data=df_correlation,annot=True,fmt=".3f",vmin=-1, vmax=1, cmap='RdYlGn')
# Out:
# <Axes: >

# %% [markdown]
# ## Time Series

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the plot style
sns.set_style('darkgrid')

# Create the line plot
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df_final[['text_score', 'gap']], ax=ax)

# Add x and y axis labels
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Text Score and Gap', fontsize=14)

# Add a title to the plot
ax.set_title('The Time Series Plot', fontsize=16)

# Customize the legend
ax.legend(labels=['Text Score', 'Gap'], fontsize=12)

# Display the plot
plt.show()

# %%
# Set the plot style
sns.set_style('darkgrid')

# Create the line plot
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df_final[['emotion_score', 'gap']], ax=ax)

# Add x and y axis labels
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Emotion Score and Gap', fontsize=14)

# Add a title to the plot
ax.set_title('The Time Series Plot', fontsize=16)

# Customize the legend
ax.legend(labels=['Emotion Score', 'Gap'], fontsize=12)

# Display the plot
plt.show()

# %%
# Set the plot style
sns.set_style('darkgrid')

# Create the line plot
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df_final[['content_score', 'gap']], ax=ax)

# Add x and y axis labels
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Content Score and Gap', fontsize=14)

# Add a title to the plot
ax.set_title('The Time Series Plot', fontsize=16)

# Customize the legend
ax.legend(labels=['Content Score', 'Gap'], fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd
import statsmodels.api as sm

# load the data
data = pd.read_csv('/content/FT_S&P500_final.csv')

# define the independent and dependent variables
X = data['text_score']
y = data['gap']

# add a constant to the independent variable
X = sm.add_constant(X)

# fit the logistic regression model
model = sm.Logit(y, X).fit()

# print the summary of the model
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.552173
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    gap   No. Observations:                   90
# Model:                          Logit   Df Residuals:                       88
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 20 Apr 2023   Pseudo R-squ.:                  0.2031
# Time:                        14:54:57   Log-Likelihood:                -49.696
# converged:                       True   LL-Null:                       -62.361
# Covariance Type:            nonrobust   LLR p-value:                 4.829e-07
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.1972      0.809     -3.950      0.000      -4.784      -1.611
# text_score     3.5679      0.857      4.162      0.000       1.888       5.248
# ==============================================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of values for the independent variable
x = np.linspace(data['text_score'].min(), data['text_score'].max(), 100)

# Calculate the predicted probabilities for the range of x values
pred_probs = 1 / (1 + np.exp(-(model.params['const'] + model.params['text_score']*x)))

# Plot the predicted probabilities against the independent variable
plt.scatter(data['text_score'], data['gap'])
plt.plot(x, pred_probs, color='red')
plt.xlabel('Text Score')
plt.ylabel('Gap')
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm

# load the data
data = pd.read_csv('/content/FT_S&P500_final.csv')

# define the independent and dependent variables
X = data['emotion_score']
y = data['gap']

# add a constant to the independent variable
X = sm.add_constant(X)

# fit the logistic regression model
model = sm.Logit(y, X).fit()

# print the summary of the model
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.686620
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    gap   No. Observations:                   90
# Model:                          Logit   Df Residuals:                       88
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 20 Apr 2023   Pseudo R-squ.:                0.009064
# Time:                        18:00:40   Log-Likelihood:                -61.796
# converged:                       True   LL-Null:                       -62.361
# Covariance Type:            nonrobust   LLR p-value:                    0.2877
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0657      0.213      0.308      0.758      -0.353       0.484
# emotion_score     0.6390      0.614      1.040      0.298      -0.565       1.843
# =================================================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of values for the independent variable
x = np.linspace(data['emotion_score'].min(), data['emotion_score'].max(), 100)

# Calculate the predicted probabilities for the range of x values
pred_probs = 1 / (1 + np.exp(-(model.params['const'] + model.params['emotion_score']*x)))

# Plot the predicted probabilities against the independent variable
plt.scatter(data['emotion_score'], data['gap'])
plt.plot(x, pred_probs, color='red')
plt.xlabel('Emotion Score')
plt.ylabel('Gap')
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm

# load the data
data = pd.read_csv('/content/FT_S&P500_final.csv')

# define the independent and dependent variables
X = data['total_score']
y = data['gap']

# add a constant to the independent variable
X = sm.add_constant(X)

# fit the logistic regression model
model = sm.Logit(y, X).fit()

# print the summary of the model
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.606195
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    gap   No. Observations:                   90
# Model:                          Logit   Df Residuals:                       88
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 20 Apr 2023   Pseudo R-squ.:                  0.1251
# Time:                        15:33:33   Log-Likelihood:                -54.558
# converged:                       True   LL-Null:                       -62.361
# Covariance Type:            nonrobust   LLR p-value:                 7.797e-05
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -1.5434      0.520     -2.969      0.003      -2.562      -0.525
# total_score     1.7549      0.517      3.392      0.001       0.741       2.769
# ===============================================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of values for the independent variable
x = np.linspace(data['total_score'].min(), data['total_score'].max(), 100)

# Calculate the predicted probabilities for the range of x values
pred_probs = 1 / (1 + np.exp(-(model.params['const'] + model.params['total_score']*x)))

# Plot the predicted probabilities against the independent variable
plt.scatter(data['total_score'], data['gap'])
plt.plot(x, pred_probs, color='red')
plt.xlabel('Total Score')
plt.ylabel('Gap')
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm

# load the data
data = pd.read_csv('/content/FT_S&P500_final.csv')

# define the independent and dependent variables
X = data['content_score']
y = data['gap']

# add a constant to the independent variable
X = sm.add_constant(X)

# fit the logistic regression model
model = sm.Logit(y, X).fit()

# print the summary of the model
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.566312
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    gap   No. Observations:                   90
# Model:                          Logit   Df Residuals:                       88
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 20 Apr 2023   Pseudo R-squ.:                  0.1827
# Time:                        17:47:11   Log-Likelihood:                -50.968
# converged:                       True   LL-Null:                       -62.361
# Covariance Type:            nonrobust   LLR p-value:                 1.811e-06
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -2.8988      0.762     -3.803      0.000      -4.393      -1.405
# content_score     3.1648      0.785      4.032      0.000       1.626       4.703
# =================================================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of values for the independent variable
x = np.linspace(data['content_score'].min(), data['content_score'].max(), 100)

# Calculate the predicted probabilities for the range of x values
pred_probs = 1 / (1 + np.exp(-(model.params['const'] + model.params['content_score']*x)))

# Plot the predicted probabilities against the independent variable
plt.scatter(data['content_score'], data['gap'])
plt.plot(x, pred_probs, color='red')
plt.xlabel('Content Score')
plt.ylabel('Gap')
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm

# load the data
data = pd.read_csv('/content/FT_S&P500_final.csv')

# define the independent and dependent variables
X = data['title_score']
y = data['gap']

# add a constant to the independent variable
X = sm.add_constant(X)

# fit the logistic regression model
model = sm.Logit(y, X).fit()

# print the summary of the model
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.548945
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    gap   No. Observations:                   90
# Model:                          Logit   Df Residuals:                       88
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 20 Apr 2023   Pseudo R-squ.:                  0.2078
# Time:                        17:51:04   Log-Likelihood:                -49.405
# converged:                       True   LL-Null:                       -62.361
# Covariance Type:            nonrobust   LLR p-value:                 3.573e-07
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -4.2753      1.056     -4.048      0.000      -6.345      -2.205
# title_score     4.3559      1.044      4.173      0.000       2.310       6.402
# ===============================================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of values for the independent variable
x = np.linspace(data['title_score'].min(), data['title_score'].max(), 100)

# Calculate the predicted probabilities for the range of x values
pred_probs = 1 / (1 + np.exp(-(model.params['const'] + model.params['title_score']*x)))

# Plot the predicted probabilities against the independent variable
plt.scatter(data['title_score'], data['gap'])
plt.plot(x, pred_probs, color='red')
plt.xlabel('Title Score')
plt.ylabel('Gap')
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm

# load the data
data = pd.read_csv('/content/FT_S&P500_final.csv')

# define the independent and dependent variables
X = data['description_score']
y = data['gap']

# add a constant to the independent variable
X = sm.add_constant(X)

# fit the logistic regression model
model = sm.Logit(y, X).fit()

# print the summary of the model
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.534188
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    gap   No. Observations:                   90
# Model:                          Logit   Df Residuals:                       88
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 20 Apr 2023   Pseudo R-squ.:                  0.2291
# Time:                        17:58:24   Log-Likelihood:                -48.077
# converged:                       True   LL-Null:                       -62.361
# Covariance Type:            nonrobust   LLR p-value:                 9.045e-08
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -3.6254      0.880     -4.121      0.000      -5.350      -1.901
# description_score     3.9363      0.909      4.328      0.000       2.154       5.719
# =====================================================================================

# %% [markdown]
# #Linear Regression

# %%
import pandas as pd
import statsmodels.api as sm

# Load data into a pandas dataframe
data = pd.read_csv('/content/FT_S&P500_final.csv')

# Select the two variables to test
X = data['news_amount']
y = data['Volume']

# Add a constant to the independent variable
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Volume   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     6.372
# Date:                Thu, 20 Apr 2023   Prob (F-statistic):             0.0134
# Time:                        14:58:40   Log-Likelihood:                -1983.0
# No. Observations:                  90   AIC:                             3970.
# Df Residuals:                      88   BIC:                             3975.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        3.576e+09   2.84e+08     12.575      0.000    3.01e+09    4.14e+09
# news_amount  6.586e+07   2.61e+07      2.524      0.013     1.4e+07    1.18e+08
# ==============================================================================
# Omnibus:                       73.536   Durbin-Watson:                   0.900
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              511.722
# Skew:                           2.571   Prob(JB):                    7.60e-112
# Kurtosis:                      13.489   Cond. No.                         32.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import matplotlib.pyplot as plt

# Visualize the data and the regression line
plt.scatter(X['news_amount'], y, alpha=0.5)
plt.plot(X['news_amount'], model.predict(X), color='red')

# Add labels and title to the plot
plt.xlabel('News Amount')
plt.ylabel('Volume')
plt.title('Linear Regression Model')

# Show the plot
plt.show()
